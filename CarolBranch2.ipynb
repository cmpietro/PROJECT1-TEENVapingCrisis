# %%
# Include this line to make plots interactive
# %matplotlib notebook

# %%
import requests 
import json
import pandas as pd
import numpy as np
from scipy import stats
from sodapy import Socrata
import matplotlib.pyplot as plt
# %matplotlib inline
import gmaps
from pandas.io.json import json_normalize

#set ggplot style
plt.style.use('ggplot')

# %%
client = Socrata("chronicdata.cdc.gov", None)
url = "https://chronicdata.cdc.gov/resource/rb39-ixr6.json"
results = client.get("rb39-ixr6", limit=38708)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#results

# %%
#print(requests.get(url))

# %%
#print(requests.get(url).json())

# %%
#response = requests.get(url).json()
#print(json.dumps(response, indent = 4, sort_keys=True))
#marked out due to API stuff discussed with Brent

# %%
health_df = pd.DataFrame(results)
health_df.count()
# Out:
# :@computed_region_bxsw_vy29    37220
# :@computed_region_he4y_prf8    37750
# age                            38708
# data_value                     24275
# data_value_footnote            14433
# data_value_footnote_symbol     14433
# data_value_std_err             24275
# data_value_type                38708
# data_value_unit                38708
# datasource                     38708
# displayorder                   38708
# education                      38708
# gender                         38708
# geolocation                    38708
# high_confidence_limit          24275
# locationabbr                   38708
# locationdesc                   38708
# low_confidence_limit           24275
# measuredesc                    38708
# measureid                      38708
# race                           38708
# response                       38708
# sample_size                    24275
# stratificationid1              38708
# stratificationid2              38708
# stratificationid3              38708
# stratificationid4              38708
# submeasure                     38708
# submeasureid                   38708
# topicdesc                      38708
# topicid                        38708
# topictype                      38708
# topictypeid                    38708
# year                           38708
# dtype: int64

# %%
#Collecting a list of all columns within the DataFrame/
health_df.columns
# Out:
# Index([':@computed_region_bxsw_vy29', ':@computed_region_he4y_prf8', 'age',
#        'data_value', 'data_value_footnote', 'data_value_footnote_symbol',
#        'data_value_std_err', 'data_value_type', 'data_value_unit',
#        'datasource', 'displayorder', 'education', 'gender', 'geolocation',
#        'high_confidence_limit', 'locationabbr', 'locationdesc',
#        'low_confidence_limit', 'measuredesc', 'measureid', 'race', 'response',
#        'sample_size', 'stratificationid1', 'stratificationid2',
#        'stratificationid3', 'stratificationid4', 'submeasure', 'submeasureid',
#        'topicdesc', 'topicid', 'topictype', 'topictypeid', 'year'],
#       dtype='object')

# %%
# Reorganizing the columns using double brackets
organized_df = health_df[["locationabbr","year","locationdesc","topicdesc","measuredesc","submeasure","data_value","sample_size","gender","age","race","education", "geolocation"]]
organized_df.head
# Out:
# <bound method NDFrame.head of       locationabbr  year    locationdesc                      topicdesc  \
# 0               NM  2011      New Mexico              Cigar Use (Youth)
# 1               OK  2005        Oklahoma              Cigar Use (Youth)
# 2               NY  2005        New York  Smokeless Tobacco Use (Youth)
# 3               AL  1997         Alabama  Smokeless Tobacco Use (Youth)
# 4               SC  2007  South Carolina              Cigar Use (Youth)
# 5               DE  2005        Delaware  Smokeless Tobacco Use (Youth)
# 6               SD  2013    South Dakota  Smokeless Tobacco Use (Youth)
# 7               AL  2005         Alabama  Smokeless Tobacco Use (Youth)
# 8               SD  2009    South Dakota  Smokeless Tobacco Use (Youth)
# 9               UT  1997            Utah          Cigarette Use (Youth)
# 10              RI  2015    Rhode Island  Smokeless Tobacco Use (Youth)
# 11              ND  2013    North Dakota              Cigar Use (Youth)
# 12              RI  1997    Rhode Island          Cigarette Use (Youth)
# 13              VT  2011         Vermont          Cigarette Use (Youth)
# 14              WY  2015         Wyoming              Cigar Use (Youth)
# 15              NC  1995  North Carolina  Smokeless Tobacco Use (Youth)
# 16              SC  2011  South Carolina              Cigar Use (Youth)
# 17              DE  2007        Delaware  Smokeless Tobacco Use (Youth)
# 18              WV  2015   West Virginia  Smokeless Tobacco Use (Youth)
# 19              ME  2007           Maine          Cigarette Use (Youth)
# 20              HI  2011          Hawaii          Cigarette Use (Youth)
# 21              AK  2009          Alaska  Smokeless Tobacco Use (Youth)
# 22              KS  2005          Kansas  Smokeless Tobacco Use (Youth)
# 23              SC  2015  South Carolina        E-Cigarette Use (Youth)
# 24              AZ  2015         Arizona              Cigar Use (Youth)
# 25              GA  2005         Georgia          Cigarette Use (Youth)
# 26              AK  2013          Alaska          Cigarette Use (Youth)
# 27              MS  2007     Mississippi              Cigar Use (Youth)
# 28              UT  2009            Utah          Cigarette Use (Youth)
# 29              AZ  2015         Arizona          Cigarette Use (Youth)
# ...            ...   ...             ...                            ...
# 38678           AK  2011          Alaska          Cigarette Use (Youth)
# 38679           VT  2001         Vermont  Smokeless Tobacco Use (Youth)
# 38680           AK  2007          Alaska          Cigarette Use (Youth)
# 38681           KY  2013        Kentucky          Cigarette Use (Youth)
# 38682           WV  2015   West Virginia        E-Cigarette Use (Youth)
# 38683           NH  2007   New Hampshire  Smokeless Tobacco Use (Youth)
# 38684           VT  2011         Vermont          Cigarette Use (Youth)
# 38685           OK  2015        Oklahoma        E-Cigarette Use (Youth)
# 38686           ME  2005           Maine          Cigarette Use (Youth)
# 38687           AR  2009        Arkansas          Cigarette Use (Youth)
# 38688           NV  2003          Nevada  Smokeless Tobacco Use (Youth)
# 38689           NC  1993  North Carolina          Cigarette Use (Youth)
# 38690           WV  2007   West Virginia          Cigarette Use (Youth)
# 38691           WV  2003   West Virginia  Smokeless Tobacco Use (Youth)
# 38692           HI  2011          Hawaii          Cigarette Use (Youth)
# 38693           CT  2013     Connecticut          Cigarette Use (Youth)
# 38694           RI  2015    Rhode Island  Smokeless Tobacco Use (Youth)
# 38695           NY  2015        New York          Cigarette Use (Youth)
# 38696           IN  2007         Indiana          Cigarette Use (Youth)
# 38697           TN  2015       Tennessee              Cigar Use (Youth)
# 38698           KS  2013          Kansas  Smokeless Tobacco Use (Youth)
# 38699           FL  2015         Florida          Cigarette Use (Youth)
# 38700           MA  1999   Massachusetts  Smokeless Tobacco Use (Youth)
# 38701           DE  1999        Delaware  Smokeless Tobacco Use (Youth)
# 38702           NJ  2013      New Jersey          Cigarette Use (Youth)
# 38703           RI  2011    Rhode Island  Smokeless Tobacco Use (Youth)
# 38704           MD  2007        Maryland  Smokeless Tobacco Use (Youth)
# 38705           GA  2009         Georgia              Cigar Use (Youth)
# 38706           VT  2015         Vermont              Cigar Use (Youth)
# 38707           RI  2015    Rhode Island        E-Cigarette Use (Youth)
#
#           measuredesc                       submeasure data_value sample_size  \
# 0      Smoking Status            Frequent Cigar Smoker        NaN         NaN
# 1      Smoking Status            Frequent Cigar Smoker        3.1         128
# 2         User Status  Frequent Smokeless Tobacco User        1.4         700
# 3         User Status  Frequent Smokeless Tobacco User        NaN         NaN
# 4      Smoking Status            Frequent Cigar Smoker        0.2         694
# 5         User Status   Current Smokeless Tobacco User        5.1        2684
# 6         User Status  Frequent Smokeless Tobacco User        NaN         NaN
# 7         User Status  Frequent Smokeless Tobacco User        0.1         570
# 8         User Status   Current Smokeless Tobacco User        5.5        1069
# 9      Smoking Status            Ever Cigarette Smoker        NaN         NaN
# 10        User Status   Current Smokeless Tobacco User        NaN         NaN
# 11     Smoking Status            Frequent Cigar Smoker        2.2        1006
# 12     Smoking Status        Frequent Cigarette Smoker       19.3        1457
# 13     Smoking Status         Current Cigarette Smoker       15.1         229
# 14     Smoking Status            Frequent Cigar Smoker        0.8        1203
# 15        User Status   Current Smokeless Tobacco User        NaN         NaN
# 16     Smoking Status            Frequent Cigar Smoker        1.8         683
# 17        User Status   Current Smokeless Tobacco User        4.9         131
# 18        User Status   Current Smokeless Tobacco User        6.9        1829
# 19     Smoking Status            Ever Cigarette Smoker        NaN         NaN
# 20     Smoking Status            Ever Cigarette Smoker        NaN         NaN
# 21        User Status   Current Smokeless Tobacco User        7.4         699
# 22        User Status   Current Smokeless Tobacco User        NaN         NaN
# 23        User Status            Ever E-Cigarette User       42.1         119
# 24     Smoking Status             Current Cigar Smoker       20.4         181
# 25     Smoking Status            Ever Cigarette Smoker       25.9         970
# 26     Smoking Status        Frequent Cigarette Smoker        3.7         599
# 27     Smoking Status             Current Cigar Smoker        NaN         NaN
# 28     Smoking Status            Ever Cigarette Smoker       23.5        1496
# 29     Smoking Status         Current Cigarette Smoker        9.3        1306
# ...               ...                              ...        ...         ...
# 38678  Smoking Status            Ever Cigarette Smoker       43.7         115
# 38679     User Status   Current Smokeless Tobacco User       19.4         101
# 38680  Smoking Status         Current Cigarette Smoker       15.9         620
# 38681  Smoking Status        Frequent Cigarette Smoker        1.8        1650
# 38682     User Status         Current E-Cigarette User        NaN         NaN
# 38683     User Status   Current Smokeless Tobacco User        NaN         NaN
# 38684  Smoking Status         Current Cigarette Smoker        NaN         NaN
# 38685     User Status        Frequent E-Cigarette User        NaN         NaN
# 38686  Smoking Status            Ever Cigarette Smoker        NaN         NaN
# 38687  Smoking Status         Current Cigarette Smoker       23.9         969
# 38688     User Status   Current Smokeless Tobacco User        6.1         878
# 38689  Smoking Status         Current Cigarette Smoker        NaN         NaN
# 38690  Smoking Status        Frequent Cigarette Smoker        NaN         NaN
# 38691     User Status  Frequent Smokeless Tobacco User        NaN         NaN
# 38692  Smoking Status        Frequent Cigarette Smoker        0.9        4972
# 38693  Smoking Status         Current Cigarette Smoker       14.8        1504
# 38694     User Status   Current Smokeless Tobacco User        0.8         271
# 38695  Smoking Status         Current Cigarette Smoker       20.4         138
# 38696  Smoking Status        Frequent Cigarette Smoker       10.4        1185
# 38697  Smoking Status             Current Cigar Smoker       13.5        1968
# 38698     User Status  Frequent Smokeless Tobacco User        2.6        1324
# 38699  Smoking Status        Frequent Cigarette Smoker        3.8        3029
# 38700     User Status  Frequent Smokeless Tobacco User        0.8        3100
# 38701     User Status  Frequent Smokeless Tobacco User        1.3        1023
# 38702  Smoking Status        Frequent Cigarette Smoker        NaN         NaN
# 38703     User Status  Frequent Smokeless Tobacco User          1         114
# 38704     User Status   Current Smokeless Tobacco User        5.1         637
# 38705  Smoking Status            Frequent Cigar Smoker        1.6         735
# 38706  Smoking Status            Frequent Cigar Smoker        0.7       10217
# 38707     User Status            Ever E-Cigarette User       17.2        1221
#
#         gender       age                           race      education  \
# 0      Overall  All Ages               Pacific Islander  Middle School
# 1      Overall  All Ages                       Hispanic    High School
# 2      Overall  All Ages                          Asian    High School
# 3      Overall  All Ages                          Asian    High School
# 4       Female  All Ages                      All Races    High School
# 5      Overall  All Ages                      All Races    High School
# 6      Overall  All Ages               African American    High School
# 7       Female  All Ages                      All Races    High School
# 8       Female  All Ages                      All Races    High School
# 9      Overall  All Ages                          Asian    High School
# 10     Overall  All Ages                          Asian  Middle School
# 11        Male  All Ages                      All Races    High School
# 12     Overall  All Ages                      All Races    High School
# 13     Overall  All Ages               African American    High School
# 14      Female  All Ages                      All Races    High School
# 15     Overall  All Ages                          Asian    High School
# 16      Female  All Ages                      All Races    High School
# 17     Overall  All Ages                  Multiple Race    High School
# 18     Overall  All Ages                      All Races  Middle School
# 19     Overall  All Ages                       Hispanic  Middle School
# 20     Overall  All Ages  American Indian/Alaska Native    High School
# 21      Female  All Ages                      All Races    High School
# 22     Overall  All Ages               Pacific Islander    High School
# 23     Overall  All Ages                       Hispanic    High School
# 24     Overall  All Ages  American Indian/Alaska Native    High School
# 25      Female  All Ages                      All Races  Middle School
# 26      Female  All Ages                      All Races    High School
# 27     Overall  All Ages                       Hispanic    High School
# 28     Overall  All Ages                      All Races    High School
# 29     Overall  All Ages                       Hispanic    High School
# ...        ...       ...                            ...            ...
# 38678  Overall  All Ages                  Multiple Race    High School
# 38679  Overall  All Ages                       Hispanic    High School
# 38680     Male  All Ages                      All Races    High School
# 38681  Overall  All Ages                      All Races  Middle School
# 38682  Overall  All Ages  American Indian/Alaska Native    High School
# 38683  Overall  All Ages  American Indian/Alaska Native    High School
# 38684  Overall  All Ages               African American  Middle School
# 38685  Overall  All Ages               African American    High School
# 38686  Overall  All Ages                          Asian  Middle School
# 38687  Overall  All Ages                          White    High School
# 38688     Male  All Ages                      All Races    High School
# 38689  Overall  All Ages                          Asian    High School
# 38690  Overall  All Ages               African American    High School
# 38691  Overall  All Ages                          Asian    High School
# 38692  Overall  All Ages                      All Races  Middle School
# 38693  Overall  All Ages                          White    High School
# 38694  Overall  All Ages               African American  Middle School
# 38695  Overall  All Ages               Pacific Islander    High School
# 38696   Female  All Ages                      All Races    High School
# 38697     Male  All Ages                      All Races    High School
# 38698  Overall  All Ages                          White    High School
# 38699     Male  All Ages                      All Races    High School
# 38700  Overall  All Ages                          White    High School
# 38701     Male  All Ages                      All Races    High School
# 38702  Overall  All Ages               Pacific Islander    High School
# 38703  Overall  All Ages                          Asian  Middle School
# 38704  Overall  All Ages                          White    High School
# 38705  Overall  All Ages               African American    High School
# 38706   Female  All Ages                      All Races    High School
# 38707     Male  All Ages                      All Races  Middle School
#
#                                              geolocation
# 0      {'type': 'Point', 'coordinates': [-106.2405809...
# 1      {'type': 'Point', 'coordinates': [-97.52107021...
# 2      {'type': 'Point', 'coordinates': [-75.54397042...
# 3      {'type': 'Point', 'coordinates': [-86.63186076...
# 4      {'type': 'Point', 'coordinates': [-81.04537120...
# 5      {'type': 'Point', 'coordinates': [-75.57774116...
# 6      {'type': 'Point', 'coordinates': [-100.3735306...
# 7      {'type': 'Point', 'coordinates': [-86.63186076...
# 8      {'type': 'Point', 'coordinates': [-100.3735306...
# 9      {'type': 'Point', 'coordinates': [-111.5871306...
# 10     {'type': 'Point', 'coordinates': [-71.52247031...
# 11     {'type': 'Point', 'coordinates': [-100.1184210...
# 12     {'type': 'Point', 'coordinates': [-71.52247031...
# 13     {'type': 'Point', 'coordinates': [-72.51764079...
# 14     {'type': 'Point', 'coordinates': [-108.1098303...
# 15     {'type': 'Point', 'coordinates': [-79.15925046...
# 16     {'type': 'Point', 'coordinates': [-81.04537120...
# 17     {'type': 'Point', 'coordinates': [-75.57774116...
# 18     {'type': 'Point', 'coordinates': [-80.71264013...
# 19     {'type': 'Point', 'coordinates': [-68.98503133...
# 20     {'type': 'Point', 'coordinates': [-157.8577494...
# 21     {'type': 'Point', 'coordinates': [-147.7220590...
# 22     {'type': 'Point', 'coordinates': [-98.20078122...
# 23     {'type': 'Point', 'coordinates': [-81.04537120...
# 24     {'type': 'Point', 'coordinates': [-111.7638112...
# 25     {'type': 'Point', 'coordinates': [-83.62758034...
# 26     {'type': 'Point', 'coordinates': [-147.7220590...
# 27     {'type': 'Point', 'coordinates': [-89.53803082...
# 28     {'type': 'Point', 'coordinates': [-111.5871306...
# 29     {'type': 'Point', 'coordinates': [-111.7638112...
# ...                                                  ...
# 38678  {'type': 'Point', 'coordinates': [-147.7220590...
# 38679  {'type': 'Point', 'coordinates': [-72.51764079...
# 38680  {'type': 'Point', 'coordinates': [-147.7220590...
# 38681  {'type': 'Point', 'coordinates': [-84.77497104...
# 38682  {'type': 'Point', 'coordinates': [-80.71264013...
# 38683  {'type': 'Point', 'coordinates': [-71.50036092...
# 38684  {'type': 'Point', 'coordinates': [-72.51764079...
# 38685  {'type': 'Point', 'coordinates': [-97.52107021...
# 38686  {'type': 'Point', 'coordinates': [-68.98503133...
# 38687  {'type': 'Point', 'coordinates': [-92.27449074...
# 38688  {'type': 'Point', 'coordinates': [-117.0718405...
# 38689  {'type': 'Point', 'coordinates': [-79.15925046...
# 38690  {'type': 'Point', 'coordinates': [-80.71264013...
# 38691  {'type': 'Point', 'coordinates': [-80.71264013...
# 38692  {'type': 'Point', 'coordinates': [-157.8577494...
# 38693  {'type': 'Point', 'coordinates': [-72.64984095...
# 38694  {'type': 'Point', 'coordinates': [-71.52247031...
# 38695  {'type': 'Point', 'coordinates': [-75.54397042...
# 38696  {'type': 'Point', 'coordinates': [-86.14996019...
# 38697  {'type': 'Point', 'coordinates': [-85.77449091...
# 38698  {'type': 'Point', 'coordinates': [-98.20078122...
# 38699  {'type': 'Point', 'coordinates': [-81.92896053...
# 38700  {'type': 'Point', 'coordinates': [-72.08269067...
# 38701  {'type': 'Point', 'coordinates': [-75.57774116...
# 38702  {'type': 'Point', 'coordinates': [-74.27369128...
# 38703  {'type': 'Point', 'coordinates': [-71.52247031...
# 38704  {'type': 'Point', 'coordinates': [-76.60926011...
# 38705  {'type': 'Point', 'coordinates': [-83.62758034...
# 38706  {'type': 'Point', 'coordinates': [-72.51764079...
# 38707  {'type': 'Point', 'coordinates': [-71.52247031...
#
# [38708 rows x 13 columns]>

# %%
latlong2 = (pd.concat({i: json_normalize(x) for i, x in organized_df.pop('geolocation').items()})
         .reset_index(level=1, drop=True)
         .join(organized_df)
         .reset_index(drop=True))
latlong2.head()

# %%
latlong3 = pd.DataFrame(latlong2["coordinates"].values.tolist())
latlong3.head()

# %%
renamedlatlong = latlong3.rename(columns={0:"Lat",1:"Lon"})
renamedlatlong.head()

# %%
new_df = pd.merge(organized_df, renamedlatlong, left_index=True, right_index=True, how='inner')
new_df.head()

# %%
organized_df = new_df
organized_df.head()

# %%
renamed_df = organized_df.rename(columns={"locationabbr":"Location Code","year":"Year","locationdesc":"State","topicdesc":"Use Type","measuredesc":"Status","submeasure":"Frequency","data_value":"% of Respondents","sample_size":"Sample Size","gender":"Gender","age":"Age","race":"Race","education":"Education"})
renamed_df.head()
# Out:
#   Location Code  Year           State                       Use Type  \
# 0            NM  2011      New Mexico              Cigar Use (Youth)
# 1            OK  2005        Oklahoma              Cigar Use (Youth)
# 2            NY  2005        New York  Smokeless Tobacco Use (Youth)
# 3            AL  1997         Alabama  Smokeless Tobacco Use (Youth)
# 4            SC  2007  South Carolina              Cigar Use (Youth)
#
#            Status                        Frequency % of Respondents  \
# 0  Smoking Status            Frequent Cigar Smoker              NaN
# 1  Smoking Status            Frequent Cigar Smoker              3.1
# 2     User Status  Frequent Smokeless Tobacco User              1.4
# 3     User Status  Frequent Smokeless Tobacco User              NaN
# 4  Smoking Status            Frequent Cigar Smoker              0.2
#
#   Sample Size   Gender       Age              Race      Education  \
# 0         NaN  Overall  All Ages  Pacific Islander  Middle School
# 1         128  Overall  All Ages          Hispanic    High School
# 2         700  Overall  All Ages             Asian    High School
# 3         NaN  Overall  All Ages             Asian    High School
# 4         694   Female  All Ages         All Races    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-106.2405809...
# 1  {'type': 'Point', 'coordinates': [-97.52107021...
# 2  {'type': 'Point', 'coordinates': [-75.54397042...
# 3  {'type': 'Point', 'coordinates': [-86.63186076...
# 4  {'type': 'Point', 'coordinates': [-81.04537120...

# %%
Minus_Nat= renamed_df.loc[renamed_df["State"] !="National (States and DC)"]
Minus_PR = Minus_Nat.loc[Minus_Nat["State"] !="Puerto Rico"]
Minus_NatPRGuam = Minus_PR.loc[Minus_PR["State"] !="Guam"]
Minus_NatPRGuam.head()
#Minus_Ohio['C'] = np.arange(len(Minus_Ohio))
#print (Minus_Ohio)
# Out:
#   Location Code  Year           State                       Use Type  \
# 0            NM  2011      New Mexico              Cigar Use (Youth)
# 1            OK  2005        Oklahoma              Cigar Use (Youth)
# 2            NY  2005        New York  Smokeless Tobacco Use (Youth)
# 3            AL  1997         Alabama  Smokeless Tobacco Use (Youth)
# 4            SC  2007  South Carolina              Cigar Use (Youth)
#
#            Status                        Frequency % of Respondents  \
# 0  Smoking Status            Frequent Cigar Smoker              NaN
# 1  Smoking Status            Frequent Cigar Smoker              3.1
# 2     User Status  Frequent Smokeless Tobacco User              1.4
# 3     User Status  Frequent Smokeless Tobacco User              NaN
# 4  Smoking Status            Frequent Cigar Smoker              0.2
#
#   Sample Size   Gender       Age              Race      Education  \
# 0         NaN  Overall  All Ages  Pacific Islander  Middle School
# 1         128  Overall  All Ages          Hispanic    High School
# 2         700  Overall  All Ages             Asian    High School
# 3         NaN  Overall  All Ages             Asian    High School
# 4         694   Female  All Ages         All Races    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-106.2405809...
# 1  {'type': 'Point', 'coordinates': [-97.52107021...
# 2  {'type': 'Point', 'coordinates': [-75.54397042...
# 3  {'type': 'Point', 'coordinates': [-86.63186076...
# 4  {'type': 'Point', 'coordinates': [-81.04537120...

# %%
USA=Minus_NatPRGuam.dropna(how='any')
USA.head()
USA.count()

# %%
USA=Minus_NatPRGuam.dropna(how='any')
USA.head()
# Out:
#   Location Code  Year           State                       Use Type  \
# 1            OK  2005        Oklahoma              Cigar Use (Youth)
# 2            NY  2005        New York  Smokeless Tobacco Use (Youth)
# 4            SC  2007  South Carolina              Cigar Use (Youth)
# 5            DE  2005        Delaware  Smokeless Tobacco Use (Youth)
# 7            AL  2005         Alabama  Smokeless Tobacco Use (Youth)
#
#            Status                        Frequency % of Respondents  \
# 1  Smoking Status            Frequent Cigar Smoker              3.1
# 2     User Status  Frequent Smokeless Tobacco User              1.4
# 4  Smoking Status            Frequent Cigar Smoker              0.2
# 5     User Status   Current Smokeless Tobacco User              5.1
# 7     User Status  Frequent Smokeless Tobacco User              0.1
#
#   Sample Size   Gender       Age       Race    Education  \
# 1         128  Overall  All Ages   Hispanic  High School
# 2         700  Overall  All Ages      Asian  High School
# 4         694   Female  All Ages  All Races  High School
# 5        2684  Overall  All Ages  All Races  High School
# 7         570   Female  All Ages  All Races  High School
#
#                                          geolocation
# 1  {'type': 'Point', 'coordinates': [-97.52107021...
# 2  {'type': 'Point', 'coordinates': [-75.54397042...
# 4  {'type': 'Point', 'coordinates': [-81.04537120...
# 5  {'type': 'Point', 'coordinates': [-75.57774116...
# 7  {'type': 'Point', 'coordinates': [-86.63186076...

# %%
USA[['% of Respondents']]=USA[['% of Respondents']].astype(float)

# %%
# Finding Average & Using GroupBy in order to separate the data into fields according to "Year and "Gender" values
grouped_usa_df = USA.groupby(['Year','Gender']).mean()

# %%
# Use unstack() to Plot all users response as a line chart

fig, ax = plt.subplots(figsize=(8,8))
grouped_usa_df.unstack().plot(ax=ax)
plt.title("% Of Responses By Gender Over Time")
plt.xlabel("Years")
plt.ylabel("Average % Of Responses")
leg = ax.legend()

# %%
#Forming DataFrame for Just E-Cigarette User Responses over USA
USA_eCig=USA.loc[USA["Use Type"] ==("E-Cigarette Use (Youth)")]
USA_eCig.head()
# Out:
#     Location Code  Year           State                 Use Type       Status  \
# 23             SC  2015  South Carolina  E-Cigarette Use (Youth)  User Status
# 41             IN  2015         Indiana  E-Cigarette Use (Youth)  User Status
# 54             SC  2015  South Carolina  E-Cigarette Use (Youth)  User Status
# 97             MA  2015   Massachusetts  E-Cigarette Use (Youth)  User Status
# 131            AZ  2015         Arizona  E-Cigarette Use (Youth)  User Status
#
#                     Frequency  % of Respondents Sample Size   Gender  \
# 23      Ever E-Cigarette User              42.1         119  Overall
# 41   Current E-Cigarette User              23.4         118  Overall
# 54   Current E-Cigarette User              19.7        1333  Overall
# 97   Current E-Cigarette User              23.7        3077  Overall
# 131     Ever E-Cigarette User              51.6        2490  Overall
#
#           Age           Race    Education  \
# 23   All Ages       Hispanic  High School
# 41   All Ages  Multiple Race  High School
# 54   All Ages      All Races  High School
# 97   All Ages      All Races  High School
# 131  All Ages      All Races  High School
#
#                                            geolocation
# 23   {'type': 'Point', 'coordinates': [-81.04537120...
# 41   {'type': 'Point', 'coordinates': [-86.14996019...
# 54   {'type': 'Point', 'coordinates': [-81.04537120...
# 97   {'type': 'Point', 'coordinates': [-72.08269067...
# 131  {'type': 'Point', 'coordinates': [-111.7638112...

# %%
# Finding Average & Using GroupBy in order to separate the data into fields according to "Year and "Gender" values
USA_eCig_Avg = USA_eCig.groupby(['Year','Gender']).mean()

# %%
# Use unstack() to Plot the E-Cigarette users response as a line chart

fig, ax = plt.subplots(figsize=(8,8))
USA_eCig_Avg.unstack().plot(ax=ax)
plt.title("% Of Responses For E Cigarettes By Gender Over TIme")
plt.xlabel("Years")
plt.ylabel("Average % Of E-Cigarette Users Responses")
leg = ax.legend()

# %%
grouped_usa_Ethinicity = USA.groupby(['Year','Race']).mean()

# %%
fig, ax = plt.subplots(figsize=(15,15))
grouped_usa_Ethinicity.unstack().plot.bar(ax=ax)
plt.title("% Of Responses From US Teen Smokers based on Ethnicity Over Time")
plt.xlabel("Years")
plt.ylabel("Average % Of Cigarette Users Responses")
leg = ax.legend()

# %%
USA_eCig_Etinicity = USA_eCig.groupby(['Year','Race']).mean()

# %%
fig, ax = plt.subplots(figsize=(10,10))
USA_eCig_Etinicity.unstack().plot.bar(ax=ax)
plt.title("% Of Responses From US Teen E Cigarette Users based on Ethnicity From 2015-2017")
plt.xlabel("Years")
plt.ylabel("Average % Of E-Cigarette Users Responses")
leg = ax.legend()

# %%
grouped_usa_Frequency = USA.groupby(['Year']).size()
grouped_usa_Frequency
# Out:
# Year
# 1993     309
# 1995     583
# 1997     684
# 1999     868
# 2001    1186
# 2003    1448
# 2005    1701
# 2007    2096
# 2009    2337
# 2011    2543
# 2013    2784
# 2015    3770
# 2017    3966
# dtype: int64

# %%
grouped_usa_Frequency.value_counts().plot(kind='pie',figsize=(15,15))

# %%
Avg_USA=USA[['% of Respondents']]=USA[['% of Respondents']].astype(float)

# %%
National= renamed_df.loc[renamed_df["State"] =="National (States and DC)"]
National.head()
# Out:
#       Location Code  Year                     State  \
# 2366             US  2015  National (States and DC)
# 7236             US  2011  National (States and DC)
# 7244             US  1995  National (States and DC)
# 7251             US  2013  National (States and DC)
# 7261             US  2009  National (States and DC)
# 7282             US  2003  National (States and DC)
# 7283             US  2015  National (States and DC)
# 7286             US  2015  National (States and DC)
# 7289             US  2011  National (States and DC)
# 7296             US  2001  National (States and DC)
# 7300             US  1997  National (States and DC)
# 7303             US  2013  National (States and DC)
# 7326             US  2005  National (States and DC)
# 7332             US  2009  National (States and DC)
# 7334             US  2009  National (States and DC)
# 7341             US  1993  National (States and DC)
# 7342             US  2003  National (States and DC)
# 7356             US  2007  National (States and DC)
# 7363             US  2005  National (States and DC)
# 7368             US  2007  National (States and DC)
# 7380             US  2009  National (States and DC)
# 7391             US  1993  National (States and DC)
# 7396             US  2005  National (States and DC)
# 7424             US  1993  National (States and DC)
# 7426             US  2001  National (States and DC)
# 7433             US  1997  National (States and DC)
# 7436             US  1997  National (States and DC)
# 7441             US  2007  National (States and DC)
# 7442             US  2015  National (States and DC)
# 7444             US  1997  National (States and DC)
# ...             ...   ...                       ...
# 33434            US  2011  National (States and DC)
# 33435            US  2003  National (States and DC)
# 33437            US  2009  National (States and DC)
# 33438            US  2015  National (States and DC)
# 33439            US  2003  National (States and DC)
# 33440            US  2009  National (States and DC)
# 33441            US  2011  National (States and DC)
# 33442            US  2015  National (States and DC)
# 33443            US  2005  National (States and DC)
# 33444            US  2013  National (States and DC)
# 33445            US  2015  National (States and DC)
# 33446            US  2005  National (States and DC)
# 33447            US  2009  National (States and DC)
# 33448            US  2005  National (States and DC)
# 33449            US  2011  National (States and DC)
# 33450            US  2011  National (States and DC)
# 33451            US  2007  National (States and DC)
# 33452            US  2013  National (States and DC)
# 33453            US  2007  National (States and DC)
# 33454            US  2003  National (States and DC)
# 33455            US  2013  National (States and DC)
# 33456            US  2009  National (States and DC)
# 33457            US  2009  National (States and DC)
# 33458            US  2013  National (States and DC)
# 33459            US  2005  National (States and DC)
# 33460            US  2003  National (States and DC)
# 33461            US  2011  National (States and DC)
# 33462            US  2005  National (States and DC)
# 33463            US  2015  National (States and DC)
# 33464            US  2015  National (States and DC)
#
#                             Use Type          Status  \
# 2366         E-Cigarette Use (Youth)     User Status
# 7236           Cigarette Use (Youth)  Smoking Status
# 7244           Cigarette Use (Youth)  Smoking Status
# 7251           Cigarette Use (Youth)  Smoking Status
# 7261           Cigarette Use (Youth)  Smoking Status
# 7282           Cigarette Use (Youth)  Smoking Status
# 7283           Cigarette Use (Youth)  Smoking Status
# 7286           Cigarette Use (Youth)  Smoking Status
# 7289           Cigarette Use (Youth)  Smoking Status
# 7296           Cigarette Use (Youth)  Smoking Status
# 7300           Cigarette Use (Youth)  Smoking Status
# 7303           Cigarette Use (Youth)  Smoking Status
# 7326           Cigarette Use (Youth)  Smoking Status
# 7332           Cigarette Use (Youth)  Smoking Status
# 7334           Cigarette Use (Youth)  Smoking Status
# 7341           Cigarette Use (Youth)  Smoking Status
# 7342           Cigarette Use (Youth)  Smoking Status
# 7356           Cigarette Use (Youth)  Smoking Status
# 7363           Cigarette Use (Youth)  Smoking Status
# 7368           Cigarette Use (Youth)  Smoking Status
# 7380           Cigarette Use (Youth)  Smoking Status
# 7391           Cigarette Use (Youth)  Smoking Status
# 7396           Cigarette Use (Youth)  Smoking Status
# 7424           Cigarette Use (Youth)  Smoking Status
# 7426           Cigarette Use (Youth)  Smoking Status
# 7433           Cigarette Use (Youth)  Smoking Status
# 7436           Cigarette Use (Youth)  Smoking Status
# 7441           Cigarette Use (Youth)  Smoking Status
# 7442           Cigarette Use (Youth)  Smoking Status
# 7444           Cigarette Use (Youth)  Smoking Status
# ...                              ...             ...
# 33434  Smokeless Tobacco Use (Youth)     User Status
# 33435  Smokeless Tobacco Use (Youth)     User Status
# 33437  Smokeless Tobacco Use (Youth)     User Status
# 33438  Smokeless Tobacco Use (Youth)     User Status
# 33439  Smokeless Tobacco Use (Youth)     User Status
# 33440  Smokeless Tobacco Use (Youth)     User Status
# 33441  Smokeless Tobacco Use (Youth)     User Status
# 33442  Smokeless Tobacco Use (Youth)     User Status
# 33443  Smokeless Tobacco Use (Youth)     User Status
# 33444  Smokeless Tobacco Use (Youth)     User Status
# 33445  Smokeless Tobacco Use (Youth)     User Status
# 33446  Smokeless Tobacco Use (Youth)     User Status
# 33447  Smokeless Tobacco Use (Youth)     User Status
# 33448  Smokeless Tobacco Use (Youth)     User Status
# 33449  Smokeless Tobacco Use (Youth)     User Status
# 33450  Smokeless Tobacco Use (Youth)     User Status
# 33451  Smokeless Tobacco Use (Youth)     User Status
# 33452  Smokeless Tobacco Use (Youth)     User Status
# 33453  Smokeless Tobacco Use (Youth)     User Status
# 33454  Smokeless Tobacco Use (Youth)     User Status
# 33455  Smokeless Tobacco Use (Youth)     User Status
# 33456  Smokeless Tobacco Use (Youth)     User Status
# 33457  Smokeless Tobacco Use (Youth)     User Status
# 33458  Smokeless Tobacco Use (Youth)     User Status
# 33459  Smokeless Tobacco Use (Youth)     User Status
# 33460  Smokeless Tobacco Use (Youth)     User Status
# 33461  Smokeless Tobacco Use (Youth)     User Status
# 33462  Smokeless Tobacco Use (Youth)     User Status
# 33463  Smokeless Tobacco Use (Youth)     User Status
# 33464  Smokeless Tobacco Use (Youth)     User Status
#
#                              Frequency % of Respondents Sample Size   Gender  \
# 2366          Current E-Cigarette User             25.8         721  Overall
# 7236         Frequent Cigarette Smoker              5.4        7450   Female
# 7244         Frequent Cigarette Smoker              NaN         NaN  Overall
# 7251             Ever Cigarette Smoker             39.6        6467   Female
# 7261          Current Cigarette Smoker             22.5        6698  Overall
# 7282         Frequent Cigarette Smoker              3.9         372  Overall
# 7283         Frequent Cigarette Smoker              NaN         NaN  Overall
# 7286             Ever Cigarette Smoker              NaN         NaN  Overall
# 7289         Frequent Cigarette Smoker              7.4        7242     Male
# 7296             Ever Cigarette Smoker             64.8        6235  Overall
# 7300             Ever Cigarette Smoker              NaN         NaN  Overall
# 7303          Current Cigarette Smoker              8.2        2843  Overall
# 7326             Ever Cigarette Smoker             74.6         138  Overall
# 7332          Current Cigarette Smoker             19.1        8049   Female
# 7334             Ever Cigarette Smoker             46.3        7776     Male
# 7341          Current Cigarette Smoker             29.8        7669     Male
# 7342          Current Cigarette Smoker             24.9        6330  Overall
# 7356             Ever Cigarette Smoker             48.8        6853   Female
# 7363          Current Cigarette Smoker             24.1         372  Overall
# 7368         Frequent Cigarette Smoker              8.7        6572     Male
# 7380         Frequent Cigarette Smoker              4.2        4516  Overall
# 7391          Current Cigarette Smoker             15.4        3481  Overall
# 7396         Frequent Cigarette Smoker             12.4         372  Overall
# 7424         Frequent Cigarette Smoker              4.6        3481  Overall
# 7426          Current Cigarette Smoker             45.1         196  Overall
# 7433         Frequent Cigarette Smoker             16.7       15124  Overall
# 7436          Current Cigarette Smoker               34        4222  Overall
# 7441          Current Cigarette Smoker             11.6        2771  Overall
# 7442         Frequent Cigarette Smoker              3.3        7512   Female
# 7444             Ever Cigarette Smoker             70.9        7850     Male
# ...                                ...              ...         ...      ...
# 33434  Frequent Smokeless Tobacco User              4.5        7415     Male
# 33435  Frequent Smokeless Tobacco User                6         342  Overall
# 33437  Frequent Smokeless Tobacco User              6.2        7894     Male
# 33438  Frequent Smokeless Tobacco User              3.2        6719  Overall
# 33439  Frequent Smokeless Tobacco User              1.3        3526  Overall
# 33440  Frequent Smokeless Tobacco User              2.2         175  Overall
# 33441  Frequent Smokeless Tobacco User              0.3        7498   Female
# 33442  Frequent Smokeless Tobacco User              0.8        1614  Overall
# 33443  Frequent Smokeless Tobacco User              0.2        6911   Female
# 33444  Frequent Smokeless Tobacco User              3.3       13345  Overall
# 33445  Frequent Smokeless Tobacco User              1.9         707  Overall
# 33446  Frequent Smokeless Tobacco User              3.5        5813  Overall
# 33447  Frequent Smokeless Tobacco User                6         136  Overall
# 33448  Frequent Smokeless Tobacco User              3.5         138  Overall
# 33449  Frequent Smokeless Tobacco User              1.1        2650  Overall
# 33450  Frequent Smokeless Tobacco User              2.5       14967  Overall
# 33451  Frequent Smokeless Tobacco User              3.6        5587  Overall
# 33452  Frequent Smokeless Tobacco User              2.9         134  Overall
# 33453  Frequent Smokeless Tobacco User              0.4        2749  Overall
# 33454  Frequent Smokeless Tobacco User              0.7        7312   Female
# 33455  Frequent Smokeless Tobacco User              0.7        6517   Female
# 33456  Frequent Smokeless Tobacco User              4.8        6775  Overall
# 33457  Frequent Smokeless Tobacco User              3.4       16134  Overall
# 33458  Frequent Smokeless Tobacco User              1.4         119  Overall
# 33459  Frequent Smokeless Tobacco User                5        6295     Male
# 33460  Frequent Smokeless Tobacco User              1.7        3846  Overall
# 33461  Frequent Smokeless Tobacco User              3.7         629  Overall
# 33462  Frequent Smokeless Tobacco User              NaN         NaN  Overall
# 33463  Frequent Smokeless Tobacco User              0.4        7542   Female
# 33464  Frequent Smokeless Tobacco User              1.7         523  Overall
#
#             Age                           Race    Education  \
# 2366   All Ages                  Multiple Race  High School
# 7236   All Ages                      All Races  High School
# 7244   All Ages               Pacific Islander  High School
# 7251   All Ages                      All Races  High School
# 7261   All Ages                          White  High School
# 7282   All Ages                          Asian  High School
# 7283   All Ages               Pacific Islander  High School
# 7286   All Ages               Pacific Islander  High School
# 7289   All Ages                      All Races  High School
# 7296   All Ages                          White  High School
# 7300   All Ages               Pacific Islander  High School
# 7303   All Ages               African American  High School
# 7326   All Ages  American Indian/Alaska Native  High School
# 7332   All Ages                      All Races  High School
# 7334   All Ages                      All Races  High School
# 7341   All Ages                      All Races  High School
# 7342   All Ages                          White  High School
# 7356   All Ages                      All Races  High School
# 7363   All Ages                  Multiple Race  High School
# 7368   All Ages                      All Races  High School
# 7380   All Ages                       Hispanic  High School
# 7391   All Ages               African American  High School
# 7396   All Ages                  Multiple Race  High School
# 7424   All Ages               African American  High School
# 7426   All Ages  American Indian/Alaska Native  High School
# 7433   All Ages                      All Races  High School
# 7436   All Ages                       Hispanic  High School
# 7441   All Ages               African American  High School
# 7442   All Ages                      All Races  High School
# 7444   All Ages                      All Races  High School
# ...         ...                            ...          ...
# 33434  All Ages                      All Races  High School
# 33435  All Ages                  Multiple Race  High School
# 33437  All Ages                      All Races  High School
# 33438  All Ages                          White  High School
# 33439  All Ages               African American  High School
# 33440  All Ages               Pacific Islander  High School
# 33441  All Ages                      All Races  High School
# 33442  All Ages               African American  High School
# 33443  All Ages                      All Races  High School
# 33444  All Ages                      All Races  High School
# 33445  All Ages                  Multiple Race  High School
# 33446  All Ages                          White  High School
# 33447  All Ages  American Indian/Alaska Native  High School
# 33448  All Ages  American Indian/Alaska Native  High School
# 33449  All Ages               African American  High School
# 33450  All Ages                      All Races  High School
# 33451  All Ages                          White  High School
# 33452  All Ages               Pacific Islander  High School
# 33453  All Ages               African American  High School
# 33454  All Ages                      All Races  High School
# 33455  All Ages                      All Races  High School
# 33456  All Ages                          White  High School
# 33457  All Ages                      All Races  High School
# 33458  All Ages  American Indian/Alaska Native  High School
# 33459  All Ages                      All Races  High School
# 33460  All Ages                       Hispanic  High School
# 33461  All Ages                  Multiple Race  High School
# 33462  All Ages               Pacific Islander  High School
# 33463  All Ages                      All Races  High School
# 33464  All Ages                          Asian  High School
#
#                                              geolocation
# 2366   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7236   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7244   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7251   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7261   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7282   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7283   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7286   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7289   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7296   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7300   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7303   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7326   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7332   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7334   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7341   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7342   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7356   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7363   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7368   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7380   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7391   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7396   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7424   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7426   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7433   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7436   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7441   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7442   {'type': 'Point', 'coordinates': [-95.712891, ...
# 7444   {'type': 'Point', 'coordinates': [-95.712891, ...
# ...                                                  ...
# 33434  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33435  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33437  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33438  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33439  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33440  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33441  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33442  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33443  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33444  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33445  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33446  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33447  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33448  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33449  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33450  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33451  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33452  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33453  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33454  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33455  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33456  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33457  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33458  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33459  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33460  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33461  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33462  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33463  {'type': 'Point', 'coordinates': [-95.712891, ...
# 33464  {'type': 'Point', 'coordinates': [-95.712891, ...
#
# [910 rows x 13 columns]

# %%
no_null_National =National.dropna(how='any')
no_null_National.head()
# Out:
#      Location Code  Year                     State                 Use Type  \
# 2366            US  2015  National (States and DC)  E-Cigarette Use (Youth)
# 7236            US  2011  National (States and DC)    Cigarette Use (Youth)
# 7251            US  2013  National (States and DC)    Cigarette Use (Youth)
# 7261            US  2009  National (States and DC)    Cigarette Use (Youth)
# 7282            US  2003  National (States and DC)    Cigarette Use (Youth)
#
#               Status                  Frequency % of Respondents Sample Size  \
# 2366     User Status   Current E-Cigarette User             25.8         721
# 7236  Smoking Status  Frequent Cigarette Smoker              5.4        7450
# 7251  Smoking Status      Ever Cigarette Smoker             39.6        6467
# 7261  Smoking Status   Current Cigarette Smoker             22.5        6698
# 7282  Smoking Status  Frequent Cigarette Smoker              3.9         372
#
#        Gender       Age           Race    Education  \
# 2366  Overall  All Ages  Multiple Race  High School
# 7236   Female  All Ages      All Races  High School
# 7251   Female  All Ages      All Races  High School
# 7261  Overall  All Ages          White  High School
# 7282  Overall  All Ages          Asian  High School
#
#                                             geolocation
# 2366  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7236  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7251  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7261  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7282  {'type': 'Point', 'coordinates': [-95.712891, ...

# %%
Ohio_df= renamed_df.loc[renamed_df["State"] =="Ohio"]
Ohio_df.head()
# Out:
#     Location Code  Year State                       Use Type          Status  \
# 149            OH  2013  Ohio              Cigar Use (Youth)  Smoking Status
# 246            OH  2005  Ohio          Cigarette Use (Youth)  Smoking Status
# 287            OH  2007  Ohio  Smokeless Tobacco Use (Youth)     User Status
# 365            OH  1999  Ohio          Cigarette Use (Youth)  Smoking Status
# 478            OH  1999  Ohio          Cigarette Use (Youth)  Smoking Status
#
#                            Frequency % of Respondents Sample Size   Gender  \
# 149            Frequent Cigar Smoker              NaN         NaN  Overall
# 246        Frequent Cigarette Smoker              NaN         NaN  Overall
# 287  Frequent Smokeless Tobacco User              NaN         NaN  Overall
# 365            Ever Cigarette Smoker              NaN         NaN  Overall
# 478        Frequent Cigarette Smoker             22.1        1993  Overall
#
#           Age                           Race    Education  \
# 149  All Ages                          Asian  High School
# 246  All Ages                  Multiple Race  High School
# 287  All Ages  American Indian/Alaska Native  High School
# 365  All Ages                          Asian  High School
# 478  All Ages                      All Races  High School
#
#                                            geolocation
# 149  {'type': 'Point', 'coordinates': [-82.40426005...
# 246  {'type': 'Point', 'coordinates': [-82.40426005...
# 287  {'type': 'Point', 'coordinates': [-82.40426005...
# 365  {'type': 'Point', 'coordinates': [-82.40426005...
# 478  {'type': 'Point', 'coordinates': [-82.40426005...

# %%
no_null_OH =Ohio_df.dropna(how='any')
no_null_OH.head()
# Out:
#     Location Code  Year State                       Use Type          Status  \
# 478            OH  1999  Ohio          Cigarette Use (Youth)  Smoking Status
# 494            OH  2003  Ohio  Smokeless Tobacco Use (Youth)     User Status
# 572            OH  2005  Ohio          Cigarette Use (Youth)  Smoking Status
# 696            OH  2011  Ohio          Cigarette Use (Youth)  Smoking Status
# 831            OH  2013  Ohio              Cigar Use (Youth)  Smoking Status
#
#                            Frequency % of Respondents Sample Size   Gender  \
# 478        Frequent Cigarette Smoker             22.1        1993  Overall
# 494  Frequent Smokeless Tobacco User                4         544     Male
# 572         Current Cigarette Smoker             22.2         661     Male
# 696            Ever Cigarette Smoker             51.5        1339  Overall
# 831            Frequent Cigar Smoker              1.2         864  Overall
#
#           Age       Race    Education  \
# 478  All Ages  All Races  High School
# 494  All Ages  All Races  High School
# 572  All Ages  All Races  High School
# 696  All Ages  All Races  High School
# 831  All Ages      White  High School
#
#                                            geolocation
# 478  {'type': 'Point', 'coordinates': [-82.40426005...
# 494  {'type': 'Point', 'coordinates': [-82.40426005...
# 572  {'type': 'Point', 'coordinates': [-82.40426005...
# 696  {'type': 'Point', 'coordinates': [-82.40426005...
# 831  {'type': 'Point', 'coordinates': [-82.40426005...

# %%
no_null_National.dtypes
# Out:
# Location Code       object
# Year                object
# State               object
# Use Type            object
# Status              object
# Frequency           object
# % of Respondents    object
# Sample Size         object
# Gender              object
# Age                 object
# Race                object
# Education           object
# geolocation         object
# dtype: object

# %%
#no_null_State.t0 float

no_null_National[['% of Respondents']]=no_null_National[['% of Respondents']].astype(float)

# %%
no_null_OH[['% of Respondents']]=no_null_OH[['% of Respondents']].astype(float)

# %%
no_null_OH.dtypes
# Out:
# Location Code        object
# Year                 object
# State                object
# Use Type             object
# Status               object
# Frequency            object
# % of Respondents    float64
# Sample Size          object
# Gender               object
# Age                  object
# Race                 object
# Education            object
# geolocation          object
# dtype: object

# %%
#state_counts = converted_df["Race"].value_counts()
#state_counts.head()
# Finding the average weight of all students
#no_null_State["% of Respondents"].mean()

# %%
no_null_National.dtypes
# Out:
# Location Code        object
# Year                 object
# State                object
# Use Type             object
# Status               object
# Frequency            object
# % of Respondents    float64
# Sample Size          object
# Gender               object
# Age                  object
# Race                 object
# Education            object
# geolocation          object
# dtype: object

# %%
# USA[['% of Respondents']]=USA[['% of Respondents']].astype(float)

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_OH_df = no_null_OH.groupby(['Location Code','Year','Use Type','Status','Frequency','Gender','Age','Race','Education'])


# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_OH_df)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000018FDD7CF358>

# %%
grouped_OH_comparison = grouped_OH_df.mean()
grouped_OH_comparison
# Out:
#                                                                                                                                                % of Respondents
# Location Code Year Use Type                      Status         Frequency                       Gender  Age      Race             Education
# OH            1993 Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School              29.0
#                                                                                                 Male    All Ages All Races        High School              30.4
#                                                                                                 Overall All Ages African American High School              14.2
#                                                                                                                  All Races        High School              29.7
#                                                                                                                  White            High School              32.8
#                                                                 Ever Cigarette Smoker           Female  All Ages All Races        High School              66.0
#                                                                                                 Male    All Ages All Races        High School              71.0
#                                                                                                 Overall All Ages African American High School              65.1
#                                                                                                                  All Races        High School              68.6
#                                                                                                                  White            High School              68.8
#                                                                 Frequent Cigarette Smoker       Female  All Ages All Races        High School              12.3
#                                                                                                 Male    All Ages All Races        High School              16.1
#                                                                                                 Overall All Ages African American High School               3.3
#                                                                                                                  All Races        High School              14.3
#                                                                                                                  White            High School              16.6
#               1997 Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School              32.0
#                                                                                                 Male    All Ages All Races        High School              36.9
#                                                                                                 Overall All Ages African American High School              19.6
#                                                                                                                  All Races        High School              34.5
#                                                                                                                  White            High School              38.1
#                                                                 Ever Cigarette Smoker           Female  All Ages All Races        High School              67.8
#                                                                                                 Male    All Ages All Races        High School              70.5
#                                                                                                 Overall All Ages African American High School              67.3
#                                                                                                                  All Races        High School              69.2
#                                                                                                                  White            High School              69.0
#                                                                 Frequent Cigarette Smoker       Female  All Ages All Races        High School              16.4
#                                                                                                 Male    All Ages All Races        High School              19.7
#                                                                                                 Overall All Ages African American High School               6.4
#                                                                                                                  All Races        High School              18.2
#                                                                                                                  White            High School              20.5
# ...                                                                                                                                                         ...
#               2013 Cigar Use (Youth)             Smoking Status Current Cigar Smoker            Overall All Ages African American High School              11.5
#                                                                                                                  All Races        High School              11.5
#                                                                                                                  White            High School              11.6
#                                                                 Frequent Cigar Smoker           Female  All Ages All Races        High School               0.6
#                                                                                                 Male    All Ages All Races        High School               2.3
#                                                                                                 Overall All Ages African American High School               2.3
#                                                                                                                  All Races        High School               1.4
#                                                                                                                  White            High School               1.2
#                    Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School              13.4
#                                                                                                 Male    All Ages All Races        High School              16.7
#                                                                                                 Overall All Ages African American High School               9.8
#                                                                                                                  All Races        High School              15.1
#                                                                                                                  Hispanic         High School              24.9
#                                                                                                                  White            High School              15.9
#                                                                 Frequent Cigarette Smoker       Female  All Ages All Races        High School               5.1
#                                                                                                 Male    All Ages All Races        High School               8.3
#                                                                                                 Overall All Ages African American High School               3.2
#                                                                                                                  All Races        High School               6.8
#                                                                                                                  Hispanic         High School              10.6
#                                                                                                                  White            High School               7.3
#                    Smokeless Tobacco Use (Youth) User Status    Current Smokeless Tobacco User  Female  All Ages All Races        High School               1.9
#                                                                                                 Male    All Ages All Races        High School              15.1
#                                                                                                 Overall All Ages African American High School               6.1
#                                                                                                                  All Races        High School               8.6
#                                                                                                                  White            High School               9.1
#                                                                 Frequent Smokeless Tobacco User Female  All Ages All Races        High School               0.2
#                                                                                                 Male    All Ages All Races        High School               5.7
#                                                                                                 Overall All Ages African American High School               0.7
#                                                                                                                  All Races        High School               3.0
#                                                                                                                  White            High School               3.5
#
# [227 rows x 1 columns]

# %%
grouped_usa_comparison = grouped_usa_df.mean()
grouped_usa_comparison
# Out:
# % of Respondents    17.512151
# dtype: float64

# %%
#combined_df = combined_df.rename(columns={"% of Respondents_x":"% of USA","% of Respondents_y":"% of Ohio"})
#combined_df

# %%
combined_df = pd.merge(grouped_usa_comparison, grouped_OH_comparison,left_on=['Location Code','Year','Gender'],right_on=['Location Code','Year','Gender'],how="outer")
combined_df.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-a75ed65ebcac> in <module>
# ----> 1 combined_df = pd.merge(grouped_usa_comparison, grouped_OH_comparison,left_on=['Location Code','Year','Gender'],right_on=['Location Code','Year','Gender'],how="outer")
#       2 combined_df.fillna(0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     477                  suffixes=('_x', '_y'), copy=True, indicator=False,
#     478                  validate=None):
# --> 479         left = validate_operand(left)
#     480         right = validate_operand(right)
#     481         self.left = self.orig_left = left
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in validate_operand(obj)
#    1745     elif isinstance(obj, Series):
#    1746         if obj.name is None:
# -> 1747             raise ValueError('Cannot merge a Series without a name')
#    1748         else:
#    1749             return obj.to_frame()
#
# ValueError: Cannot merge a Series without a name

# %%
combined_df = combined_df.rename(columns={"% of Respondents_x":"% of USA","% of Respondents_y":"% of Ohio"})

combined_df.fillna(0)
