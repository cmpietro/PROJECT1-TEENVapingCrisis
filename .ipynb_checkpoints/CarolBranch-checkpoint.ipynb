# %%
import requests 
import json
import pandas as pd
import numpy as np
from scipy import stats
from sodapy import Socrata
import matplotlib.pyplot as plt  # added Matplotlib - for graphing (cp 6-19-19)

# %%
client = Socrata("chronicdata.cdc.gov", None)
url = "https://chronicdata.cdc.gov/resource/rb39-ixr6.json"
results = client.get("rb39-ixr6", limit=38708)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#results

# %%
#print(requests.get(url))

# %%
#print(requests.get(url).json())

# %%
#response = requests.get(url).json()
#print(json.dumps(response, indent = 4, sort_keys=True))
#marked out due to API stuff discussed with Brent

# %%
health_df = pd.DataFrame(results)
health_df.count()
# Out:
# :@computed_region_bxsw_vy29    37220
# :@computed_region_he4y_prf8    37750
# age                            38708
# data_value                     24275
# data_value_footnote            14433
# data_value_footnote_symbol     14433
# data_value_std_err             24275
# data_value_type                38708
# data_value_unit                38708
# datasource                     38708
# displayorder                   38708
# education                      38708
# gender                         38708
# geolocation                    38708
# high_confidence_limit          24275
# locationabbr                   38708
# locationdesc                   38708
# low_confidence_limit           24275
# measuredesc                    38708
# measureid                      38708
# race                           38708
# response                       38708
# sample_size                    24275
# stratificationid1              38708
# stratificationid2              38708
# stratificationid3              38708
# stratificationid4              38708
# submeasure                     38708
# submeasureid                   38708
# topicdesc                      38708
# topicid                        38708
# topictype                      38708
# topictypeid                    38708
# year                           38708
# dtype: int64

# %%
#Collecting a list of all columns within the DataFrame/
health_df.columns
# Out:
# Index([':@computed_region_bxsw_vy29', ':@computed_region_he4y_prf8', 'age',
#        'data_value', 'data_value_footnote', 'data_value_footnote_symbol',
#        'data_value_std_err', 'data_value_type', 'data_value_unit',
#        'datasource', 'displayorder', 'education', 'gender', 'geolocation',
#        'high_confidence_limit', 'locationabbr', 'locationdesc',
#        'low_confidence_limit', 'measuredesc', 'measureid', 'race', 'response',
#        'sample_size', 'stratificationid1', 'stratificationid2',
#        'stratificationid3', 'stratificationid4', 'submeasure', 'submeasureid',
#        'topicdesc', 'topicid', 'topictype', 'topictypeid', 'year'],
#       dtype='object')

# %%
# Reorganizing the columns using double brackets
organized_df = health_df[["year","locationdesc","topicdesc","measuredesc","submeasure","data_value","sample_size","gender","age","race","education", "geolocation"]]
organized_df.head()
# Out:
#    year    locationdesc                      topicdesc     measuredesc  \
# 0  2011      New Mexico              Cigar Use (Youth)  Smoking Status
# 1  2005        Oklahoma              Cigar Use (Youth)  Smoking Status
# 2  2005        New York  Smokeless Tobacco Use (Youth)     User Status
# 3  1997         Alabama  Smokeless Tobacco Use (Youth)     User Status
# 4  2007  South Carolina              Cigar Use (Youth)  Smoking Status
#
#                         submeasure data_value sample_size   gender       age  \
# 0            Frequent Cigar Smoker        NaN         NaN  Overall  All Ages
# 1            Frequent Cigar Smoker        3.1         128  Overall  All Ages
# 2  Frequent Smokeless Tobacco User        1.4         700  Overall  All Ages
# 3  Frequent Smokeless Tobacco User        NaN         NaN  Overall  All Ages
# 4            Frequent Cigar Smoker        0.2         694   Female  All Ages
#
#                race      education  \
# 0  Pacific Islander  Middle School
# 1          Hispanic    High School
# 2             Asian    High School
# 3             Asian    High School
# 4         All Races    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-106.2405809...
# 1  {'type': 'Point', 'coordinates': [-97.52107021...
# 2  {'type': 'Point', 'coordinates': [-75.54397042...
# 3  {'type': 'Point', 'coordinates': [-86.63186076...
# 4  {'type': 'Point', 'coordinates': [-81.04537120...

# %%
renamed_df = organized_df.rename(columns={"year":"Year","locationdesc":"State","topicdesc":"Use Type","measuredesc":"Status","submeasure":"Frequency","data_value":"% of Respondents","sample_size":"Sample Size","gender":"Gender","age":"Age","race":"Race","education":"Education"})
renamed_df.head()
# Out:
#    Year           State                       Use Type          Status  \
# 0  2011      New Mexico              Cigar Use (Youth)  Smoking Status
# 1  2005        Oklahoma              Cigar Use (Youth)  Smoking Status
# 2  2005        New York  Smokeless Tobacco Use (Youth)     User Status
# 3  1997         Alabama  Smokeless Tobacco Use (Youth)     User Status
# 4  2007  South Carolina              Cigar Use (Youth)  Smoking Status
#
#                          Frequency % of Respondents Sample Size   Gender  \
# 0            Frequent Cigar Smoker              NaN         NaN  Overall
# 1            Frequent Cigar Smoker              3.1         128  Overall
# 2  Frequent Smokeless Tobacco User              1.4         700  Overall
# 3  Frequent Smokeless Tobacco User              NaN         NaN  Overall
# 4            Frequent Cigar Smoker              0.2         694   Female
#
#         Age              Race      Education  \
# 0  All Ages  Pacific Islander  Middle School
# 1  All Ages          Hispanic    High School
# 2  All Ages             Asian    High School
# 3  All Ages             Asian    High School
# 4  All Ages         All Races    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-106.2405809...
# 1  {'type': 'Point', 'coordinates': [-97.52107021...
# 2  {'type': 'Point', 'coordinates': [-75.54397042...
# 3  {'type': 'Point', 'coordinates': [-86.63186076...
# 4  {'type': 'Point', 'coordinates': [-81.04537120...

# %%
Minus_NatPRGuam= renamed_df.loc[renamed_df["State"] !=("National (States and DC)", "Puerto Rico", "Guam")]
Minus_NatPRGuam.head()
#Minus_Ohio['C'] = np.arange(len(Minus_Ohio))
#print (Minus_Ohio)
# Out:
#    Year           State                       Use Type          Status  \
# 0  2011      New Mexico              Cigar Use (Youth)  Smoking Status
# 1  2005        Oklahoma              Cigar Use (Youth)  Smoking Status
# 2  2005        New York  Smokeless Tobacco Use (Youth)     User Status
# 3  1997         Alabama  Smokeless Tobacco Use (Youth)     User Status
# 4  2007  South Carolina              Cigar Use (Youth)  Smoking Status
#
#                          Frequency % of Respondents Sample Size   Gender  \
# 0            Frequent Cigar Smoker              NaN         NaN  Overall
# 1            Frequent Cigar Smoker              3.1         128  Overall
# 2  Frequent Smokeless Tobacco User              1.4         700  Overall
# 3  Frequent Smokeless Tobacco User              NaN         NaN  Overall
# 4            Frequent Cigar Smoker              0.2         694   Female
#
#         Age              Race      Education  \
# 0  All Ages  Pacific Islander  Middle School
# 1  All Ages          Hispanic    High School
# 2  All Ages             Asian    High School
# 3  All Ages             Asian    High School
# 4  All Ages         All Races    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-106.2405809...
# 1  {'type': 'Point', 'coordinates': [-97.52107021...
# 2  {'type': 'Point', 'coordinates': [-75.54397042...
# 3  {'type': 'Point', 'coordinates': [-86.63186076...
# 4  {'type': 'Point', 'coordinates': [-81.04537120...

# %%
USA=Minus_NatPRGuam.dropna(how='any')
USA.head()
# Out:
#    Year           State                       Use Type          Status  \
# 1  2005        Oklahoma              Cigar Use (Youth)  Smoking Status
# 2  2005        New York  Smokeless Tobacco Use (Youth)     User Status
# 4  2007  South Carolina              Cigar Use (Youth)  Smoking Status
# 5  2005        Delaware  Smokeless Tobacco Use (Youth)     User Status
# 7  2005         Alabama  Smokeless Tobacco Use (Youth)     User Status
#
#                          Frequency % of Respondents Sample Size   Gender  \
# 1            Frequent Cigar Smoker              3.1         128  Overall
# 2  Frequent Smokeless Tobacco User              1.4         700  Overall
# 4            Frequent Cigar Smoker              0.2         694   Female
# 5   Current Smokeless Tobacco User              5.1        2684  Overall
# 7  Frequent Smokeless Tobacco User              0.1         570   Female
#
#         Age       Race    Education  \
# 1  All Ages   Hispanic  High School
# 2  All Ages      Asian  High School
# 4  All Ages  All Races  High School
# 5  All Ages  All Races  High School
# 7  All Ages  All Races  High School
#
#                                          geolocation
# 1  {'type': 'Point', 'coordinates': [-97.52107021...
# 2  {'type': 'Point', 'coordinates': [-75.54397042...
# 4  {'type': 'Point', 'coordinates': [-81.04537120...
# 5  {'type': 'Point', 'coordinates': [-75.57774116...
# 7  {'type': 'Point', 'coordinates': [-86.63186076...

# %%
National= renamed_df.loc[renamed_df["State"] =="National (States and DC)"]
National.head()
# Out:
#       Year                     State                 Use Type          Status  \
# 2366  2015  National (States and DC)  E-Cigarette Use (Youth)     User Status
# 7236  2011  National (States and DC)    Cigarette Use (Youth)  Smoking Status
# 7244  1995  National (States and DC)    Cigarette Use (Youth)  Smoking Status
# 7251  2013  National (States and DC)    Cigarette Use (Youth)  Smoking Status
# 7261  2009  National (States and DC)    Cigarette Use (Youth)  Smoking Status
#
#                       Frequency % of Respondents Sample Size   Gender  \
# 2366   Current E-Cigarette User             25.8         721  Overall
# 7236  Frequent Cigarette Smoker              5.4        7450   Female
# 7244  Frequent Cigarette Smoker              NaN         NaN  Overall
# 7251      Ever Cigarette Smoker             39.6        6467   Female
# 7261   Current Cigarette Smoker             22.5        6698  Overall
#
#            Age              Race    Education  \
# 2366  All Ages     Multiple Race  High School
# 7236  All Ages         All Races  High School
# 7244  All Ages  Pacific Islander  High School
# 7251  All Ages         All Races  High School
# 7261  All Ages             White  High School
#
#                                             geolocation
# 2366  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7236  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7244  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7251  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7261  {'type': 'Point', 'coordinates': [-95.712891, ...

# %%
no_null_National =National.dropna(how='any')
no_null_National.head()
# Out:
#       Year                     State                 Use Type          Status  \
# 2366  2015  National (States and DC)  E-Cigarette Use (Youth)     User Status
# 7236  2011  National (States and DC)    Cigarette Use (Youth)  Smoking Status
# 7251  2013  National (States and DC)    Cigarette Use (Youth)  Smoking Status
# 7261  2009  National (States and DC)    Cigarette Use (Youth)  Smoking Status
# 7282  2003  National (States and DC)    Cigarette Use (Youth)  Smoking Status
#
#                       Frequency % of Respondents Sample Size   Gender  \
# 2366   Current E-Cigarette User             25.8         721  Overall
# 7236  Frequent Cigarette Smoker              5.4        7450   Female
# 7251      Ever Cigarette Smoker             39.6        6467   Female
# 7261   Current Cigarette Smoker             22.5        6698  Overall
# 7282  Frequent Cigarette Smoker              3.9         372  Overall
#
#            Age           Race    Education  \
# 2366  All Ages  Multiple Race  High School
# 7236  All Ages      All Races  High School
# 7251  All Ages      All Races  High School
# 7261  All Ages          White  High School
# 7282  All Ages          Asian  High School
#
#                                             geolocation
# 2366  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7236  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7251  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7261  {'type': 'Point', 'coordinates': [-95.712891, ...
# 7282  {'type': 'Point', 'coordinates': [-95.712891, ...

# %%
Ohio_df= renamed_df.loc[renamed_df["State"] =="Ohio"]
Ohio_df.head()
# Out:
#      Year State                       Use Type          Status  \
# 149  2013  Ohio              Cigar Use (Youth)  Smoking Status
# 246  2005  Ohio          Cigarette Use (Youth)  Smoking Status
# 287  2007  Ohio  Smokeless Tobacco Use (Youth)     User Status
# 365  1999  Ohio          Cigarette Use (Youth)  Smoking Status
# 478  1999  Ohio          Cigarette Use (Youth)  Smoking Status
#
#                            Frequency % of Respondents Sample Size   Gender  \
# 149            Frequent Cigar Smoker              NaN         NaN  Overall
# 246        Frequent Cigarette Smoker              NaN         NaN  Overall
# 287  Frequent Smokeless Tobacco User              NaN         NaN  Overall
# 365            Ever Cigarette Smoker              NaN         NaN  Overall
# 478        Frequent Cigarette Smoker             22.1        1993  Overall
#
#           Age                           Race    Education  \
# 149  All Ages                          Asian  High School
# 246  All Ages                  Multiple Race  High School
# 287  All Ages  American Indian/Alaska Native  High School
# 365  All Ages                          Asian  High School
# 478  All Ages                      All Races  High School
#
#                                            geolocation
# 149  {'type': 'Point', 'coordinates': [-82.40426005...
# 246  {'type': 'Point', 'coordinates': [-82.40426005...
# 287  {'type': 'Point', 'coordinates': [-82.40426005...
# 365  {'type': 'Point', 'coordinates': [-82.40426005...
# 478  {'type': 'Point', 'coordinates': [-82.40426005...

# %%
no_null_OH =Ohio_df.dropna(how='any')
no_null_OH.head()
# Out:
#      Year State                       Use Type          Status  \
# 478  1999  Ohio          Cigarette Use (Youth)  Smoking Status
# 494  2003  Ohio  Smokeless Tobacco Use (Youth)     User Status
# 572  2005  Ohio          Cigarette Use (Youth)  Smoking Status
# 696  2011  Ohio          Cigarette Use (Youth)  Smoking Status
# 831  2013  Ohio              Cigar Use (Youth)  Smoking Status
#
#                            Frequency % of Respondents Sample Size   Gender  \
# 478        Frequent Cigarette Smoker             22.1        1993  Overall
# 494  Frequent Smokeless Tobacco User                4         544     Male
# 572         Current Cigarette Smoker             22.2         661     Male
# 696            Ever Cigarette Smoker             51.5        1339  Overall
# 831            Frequent Cigar Smoker              1.2         864  Overall
#
#           Age       Race    Education  \
# 478  All Ages  All Races  High School
# 494  All Ages  All Races  High School
# 572  All Ages  All Races  High School
# 696  All Ages  All Races  High School
# 831  All Ages      White  High School
#
#                                            geolocation
# 478  {'type': 'Point', 'coordinates': [-82.40426005...
# 494  {'type': 'Point', 'coordinates': [-82.40426005...
# 572  {'type': 'Point', 'coordinates': [-82.40426005...
# 696  {'type': 'Point', 'coordinates': [-82.40426005...
# 831  {'type': 'Point', 'coordinates': [-82.40426005...

# %%
no_null_National.dtypes
# Out:
# Year                object
# State               object
# Use Type            object
# Status              object
# Frequency           object
# % of Respondents    object
# Sample Size         object
# Gender              object
# Age                 object
# Race                object
# Education           object
# geolocation         object
# dtype: object

# %%
#no_null_State.t0 float

no_null_National[['% of Respondents']]=no_null_National[['% of Respondents']].astype(float)
# Out:
# C:\Users\carol\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
no_null_OH[['% of Respondents']]=no_null_OH[['% of Respondents']].astype(float)

# %%
#state_counts = converted_df["Race"].value_counts()
#state_counts.head()
# Finding the average weight of all students
#no_null_State["% of Respondents"].mean()

# %%
no_null_National.dtypes
# Out:
# Year                 object
# State                object
# Use Type             object
# Status               object
# Frequency            object
# % of Respondents    float64
# Sample Size          object
# Gender               object
# Age                  object
# Race                 object
# Education            object
# geolocation          object
# dtype: object

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_usa_df = no_null_National.groupby(['Year','Use Type','Status','Frequency','Gender','Age','Race','Education'])


# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_usa_df)

# In order to be visualized, a data function must be used...
#grouped_usa_df.count()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E9980A8DD8>

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_OH_df = no_null_OH.groupby(['Year','Use Type','Status','Frequency','Gender','Age','Race','Education'])


# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_OH_df)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001E99A4E8048>

# %%
grouped_OH_comparison = grouped_OH_df.mean()
grouped_OH_comparison
# Out:
#                                                                                                                                  % of Respondents
# Year Use Type                      Status         Frequency                       Gender  Age      Race             Education
# 1993 Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School              29.0
#                                                                                   Male    All Ages All Races        High School              30.4
#                                                                                   Overall All Ages African American High School              14.2
#                                                                                                    All Races        High School              29.7
#                                                                                                    White            High School              32.8
#                                                   Ever Cigarette Smoker           Female  All Ages All Races        High School              66.0
#                                                                                   Male    All Ages All Races        High School              71.0
#                                                                                   Overall All Ages African American High School              65.1
#                                                                                                    All Races        High School              68.6
#                                                                                                    White            High School              68.8
#                                                   Frequent Cigarette Smoker       Female  All Ages All Races        High School              12.3
#                                                                                   Male    All Ages All Races        High School              16.1
#                                                                                   Overall All Ages African American High School               3.3
#                                                                                                    All Races        High School              14.3
#                                                                                                    White            High School              16.6
# 1997 Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School              32.0
#                                                                                   Male    All Ages All Races        High School              36.9
#                                                                                   Overall All Ages African American High School              19.6
#                                                                                                    All Races        High School              34.5
#                                                                                                    White            High School              38.1
#                                                   Ever Cigarette Smoker           Female  All Ages All Races        High School              67.8
#                                                                                   Male    All Ages All Races        High School              70.5
#                                                                                   Overall All Ages African American High School              67.3
#                                                                                                    All Races        High School              69.2
#                                                                                                    White            High School              69.0
#                                                   Frequent Cigarette Smoker       Female  All Ages All Races        High School              16.4
#                                                                                   Male    All Ages All Races        High School              19.7
#                                                                                   Overall All Ages African American High School               6.4
#                                                                                                    All Races        High School              18.2
#                                                                                                    White            High School              20.5
# ...                                                                                                                                           ...
# 2013 Cigar Use (Youth)             Smoking Status Current Cigar Smoker            Overall All Ages African American High School              11.5
#                                                                                                    All Races        High School              11.5
#                                                                                                    White            High School              11.6
#                                                   Frequent Cigar Smoker           Female  All Ages All Races        High School               0.6
#                                                                                   Male    All Ages All Races        High School               2.3
#                                                                                   Overall All Ages African American High School               2.3
#                                                                                                    All Races        High School               1.4
#                                                                                                    White            High School               1.2
#      Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School              13.4
#                                                                                   Male    All Ages All Races        High School              16.7
#                                                                                   Overall All Ages African American High School               9.8
#                                                                                                    All Races        High School              15.1
#                                                                                                    Hispanic         High School              24.9
#                                                                                                    White            High School              15.9
#                                                   Frequent Cigarette Smoker       Female  All Ages All Races        High School               5.1
#                                                                                   Male    All Ages All Races        High School               8.3
#                                                                                   Overall All Ages African American High School               3.2
#                                                                                                    All Races        High School               6.8
#                                                                                                    Hispanic         High School              10.6
#                                                                                                    White            High School               7.3
#      Smokeless Tobacco Use (Youth) User Status    Current Smokeless Tobacco User  Female  All Ages All Races        High School               1.9
#                                                                                   Male    All Ages All Races        High School              15.1
#                                                                                   Overall All Ages African American High School               6.1
#                                                                                                    All Races        High School               8.6
#                                                                                                    White            High School               9.1
#                                                   Frequent Smokeless Tobacco User Female  All Ages All Races        High School               0.2
#                                                                                   Male    All Ages All Races        High School               5.7
#                                                                                   Overall All Ages African American High School               0.7
#                                                                                                    All Races        High School               3.0
#                                                                                                    White            High School               3.5
#
# [227 rows x 1 columns]

# %%
grouped_usa_comparison = grouped_usa_df.mean()
grouped_usa_comparison
# Out:
#                                                                                                                                               % of Respondents
# Year Use Type                      Status         Frequency                       Gender  Age      Race                          Education
# 1993 Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All
smokeless Tobacco Use (Youth) User Status    Current Smokeless Tobacco User  Female  All Ages All Races        High School        1.9
#                                                                                   Male    All Ages All Races        High School       15.1
#                                                                                   Overall All Ages African American High School        6.1
#                                                                                                    All Races        High School        8.6
#                                                                                                    White            High School        9.1
#                                                   Frequent Smokeless Tobacco User Female  All Ages All Races        High School        0.2
#                                                                                   Male    All Ages All Races        High School        5.7
#                                                                                   Overall All Ages African American High School        0.7
#                                                                                                    All Races        High School        3.0
#                                                                                                    White            High School        3.5
#
# [227 rows x 2 columns]

# %%
#USA.t0 float

USA[['% of Respondents']]=USA[['% of Respondents']].astype(float)

# Store the Mean usage Data Grouped by race and year
race_usage_mean = USA.groupby(["Year", "Race"]).mean()["% of Respondents"]

# Convert to DataFrame
race_usage_mean = pd.DataFrame(race_usage_mean)

# Flatten the column headings
race_usage_mean = race_usage_mean.reset_index()

# Preview DataFrame
race_usage_mean.head()
# Out:
#    Year                           Race  % of Respondents
# 0  1993               African American         29.145455
# 1  1993                      All Races         37.243503
# 2  1993  American Indian/Alaska Native         52.700000
# 3  1993                          Asian         27.533333
# 4  1993                       Hispanic         36.980952

# %%
# Store the Standard Error of percentage used Grouped by race and year
race_usage_sem = USA.groupby(["Year", "Race"]).sem()["% of Respondents"]

# Convert to DataFrame
race_usage_sem = pd.DataFrame(race_usage_sem)

# Preview DataFrame
race_usage_sem.head().reset_index()
# Out:
#    Year                           Race  % of Respondents
# 0  1993               African American          4.957314
# 1  1993                      All Races          1.723250
# 2  1993  American Indian/Alaska Native         10.497573
# 3  1993                          Asian          5.194270
# 4  1993                       Hispanic          5.837884

# %%
# Minor Data Munging to Re-Format the Data Frames for RACE data

race_usage_mean = race_usage_mean.reset_index()
race_usage_mean_pivot = race_usage_mean.pivot(index="Year", columns="Race")["% of Respondents"]

race_usage_sem = race_usage_sem.reset_index()
race_usage_sem_pivot = race_usage_sem_pivot(index="Year", columns="Race")["% of Respondents"]

# Preview that Reformatting worked
race_usage_mean_pivot.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-33013e259b1b> in <module>
#       1 # Minor Data Munging to Re-Format the Data Frames for RACE data
#       2
# ----> 3 race_usage_mean = race_usage_mean.reset_index()
#       4 race_usage_mean_pivot = race_usage_mean.pivot(index="Year", columns="Race")["% of Respondents"]
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
# CP 6-19-19
# Ethnicity BAR Graphs using combined_df 

# Calculate the percent usage for each race
usage_mean =  100 * (usage_pivot_mean.iloc[-1] - usage_pivot_mean.iloc[0]) / usage_pivot_mean.iloc[0]
usage_sem =  100 * (usage_pivot_sem.iloc[-1] - usage_sem.iloc[0]) / tusage_pivot_sem.iloc[0]

# Display the data to confirm
usage_change

# Store all Relevant Ethnic data into a Tuple
race_data = (usage_change["All Races"], 
               usage_change["African American"], 
               usage_change["White"], 
               usage_change["Placebo"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-b081db316499> in <module>
#       3
#       4 # Calculate the percent usage for each race
# ----> 5 usage_mean =  100 * (usage_pivot_mean.iloc[-1] - usage_pivot_mean.iloc[0]) / usage_pivot_mean.iloc[0]
#       6 usage_sem =  100 * (usage_pivot_sem.iloc[-1] - usage_sem.iloc[0]) / tusage_pivot_sem.iloc[0]
#       7
#
# NameError: name 'usage_pivot_mean' is not defined
