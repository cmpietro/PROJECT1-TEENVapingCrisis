# %%
import requests 
import json
import pandas as pd

# %%
url = "https://chronicdata.cdc.gov/resource/rb39-ixr6.json"

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
#print(requests.get(url).json())

# %%
response = requests.get(url).json()
#print(json.dumps(response, indent = 4, sort_keys=True))

# %%
health_df = pd.DataFrame(response)
health_df.head()
# Out:
#   :@computed_region_bxsw_vy29 :@computed_region_he4y_prf8       age  \
# 0                          17                        1287  All Ages
# 1                          14                        3084  All Ages
# 2                          43                        1046  All Ages
# 3                          14                        3084  All Ages
# 4                          14                        3084  All Ages
#
#   data_value data_value_footnote data_value_footnote_symbol  \
# 0       39.5                 NaN                        NaN
# 1       34.6                 NaN                        NaN
# 2        8.3                 NaN                        NaN
# 3       19.6                 NaN                        NaN
# 4        4.9                 NaN                        NaN
#
#   data_value_std_err data_value_type data_value_unit datasource  ...  \
# 0                2.4      Percentage               %      YRBSS  ...
# 1                2.2      Percentage               %      YRBSS  ...
# 2                0.8      Percentage               %      YRBSS  ...
# 3                1.5      Percentage               %      YRBSS  ...
# 4                0.5      Percentage               %      YRBSS  ...
#
#   stratificationid2 stratificationid3 stratificationid4  \
# 0              8AGE              5RAC              2EDU
# 1              8AGE              6RAC              2EDU
# 2              8AGE              6RAC              1EDU
# 3              8AGE              6RAC              2EDU
# 4              8AGE              5RAC              2EDU
#
#                         submeasure submeasureid  \
# 0            Ever Cigarette Smoker        YRB03
# 1         Current Cigarette Smoker        YRB01
# 2         Current Cigarette Smoker        YRB01
# 3        Frequent Cigarette Smoker        YRB02
# 4  Frequent Smokeless Tobacco User        YRB05
#
#                        topicdesc topicid                  topictype  \
# 0          Cigarette Use (Youth)  106BEH  Tobacco Use - Survey Data
# 1          Cigarette Use (Youth)  106BEH  Tobacco Use - Survey Data
# 2          Cigarette Use (Youth)  106BEH  Tobacco Use - Survey Data
# 3          Cigarette Use (Youth)  106BEH  Tobacco Use - Survey Data
# 4  Smokeless Tobacco Use (Youth)  151BEH  Tobacco Use - Survey Data
#
#   topictypeid  year
# 0         BEH  2011
# 1         BEH  1999
# 2         BEH  2009
# 3         BEH  1995
# 4         BEH  2013
#
# [5 rows x 34 columns]

# %%
#Collecting a list of all columns within the DataFrame
health_df.columns

# %%
# Reorganizing the columns using double brackets
organized_df = health_df[["YEAR", "LocationAbbr", "TopicDesc", "Response", "Data_Value", "Gender", "Race","Education", "StratificationID1", "StratificationID2", "StratificationID3", "StratificationID4"]]
organized_df.head()

# %%
renamed_df = organized_df.rename(columns={"LocationAbbr":"State", "TopicDesc":"Use Type", "Response":"Use Frequency", "Data_Value":"% of Respondents"})
renamed_df.head()
