# %% [markdown]
# # PROJECT ONE

# %% [markdown]
# PROJECT PARTICIPANTS:  Kashifa AHMED, Charles CAMPISI, Carol PIETRO, and Ian VALENTIK

# %% [markdown]
# ## TED TALKS:  TEEN Tobacco / Nicotine Usage Trends

# %% [markdown]
# WE WONDERED:
# Is there a significant increase in teen e-cigarette usage?
# TED Talk stated a 900% increase in E-cigarette usage since 2011, can we measure that increase?
# Are their any differences in gender and ethnicity in the percentage of E-cigarette users?

# %% [markdown]
# ###### DEPENDENCIES

# %%
# Include this line to make plots interactive
# %matplotlib notebook

# %%
import warnings
warnings.filterwarnings('ignore')
import requests 
import json
import pandas as pd
import numpy as np
from scipy import stats
from sodapy import Socrata
import matplotlib.pyplot as plt
# %matplotlib inline
import gmaps
from pandas.io.json import json_normalize

#set ggplot style
plt.style.use('ggplot')

# %% [markdown]
# ###### API CALL

# %%
#Our data comes from the CDC. It is a Survey completed Biennally regarding Teen tobacco usage. Data covers from 1993 - 2017 
client = Socrata("chronicdata.cdc.gov", None)
url = "https://chronicdata.cdc.gov/resource/rb39-ixr6.json"
results = client.get("rb39-ixr6", limit=38708)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Validation of results
#results

# %%
# To print the URL
#print(requests.get(url))

# %%
# To print the URL
#print(requests.get(url).json())

# %%
# dump of the data 
#marked out due to API stuff discussed with Brent
#response = requests.get(url).json()
#print(json.dumps(response, indent = 4, sort_keys=True))

# %% [markdown]
# ###### REVIEW OF DATA FRAME AND BEGINNING OF ANALYSIS

# %%
# Define the data frame to begin review of data
health_df = pd.DataFrame(results)
health_df.count()
# Out:
# :@computed_region_bxsw_vy29    37220
# :@computed_region_he4y_prf8    37750
# age                            38708
# data_value                     24275
# data_value_footnote            14433
# data_value_footnote_symbol     14433
# data_value_std_err             24275
# data_value_type                38708
# data_value_unit                38708
# datasource                     38708
# displayorder                   38708
# education                      38708
# gender                         38708
# geolocation                    38708
# high_confidence_limit          24275
# locationabbr                   38708
# locationdesc                   38708
# low_confidence_limit           24275
# measuredesc                    38708
# measureid                      38708
# race                           38708
# response                       38708
# sample_size                    24275
# stratificationid1              38708
# stratificationid2              38708
# stratificationid3              38708
# stratificationid4              38708
# submeasure                     38708
# submeasureid                   38708
# topicdesc                      38708
# topicid                        38708
# topictype                      38708
# topictypeid                    38708
# year                           38708
# dtype: int64

# %%
#Collecting a list of all columns within the DataFrame/
health_df.columns
# Out:
# Index([':@computed_region_bxsw_vy29', ':@computed_region_he4y_prf8', 'age',
#        'data_value', 'data_value_footnote', 'data_value_footnote_symbol',
#        'data_value_std_err', 'data_value_type', 'data_value_unit',
#        'datasource', 'displayorder', 'education', 'gender', 'geolocation',
#        'high_confidence_limit', 'locationabbr', 'locationdesc',
#        'low_confidence_limit', 'measuredesc', 'measureid', 'race', 'response',
#        'sample_size', 'stratificationid1', 'stratificationid2',
#        'stratificationid3', 'stratificationid4', 'submeasure', 'submeasureid',
#        'topicdesc', 'topicid', 'topictype', 'topictypeid', 'year'],
#       dtype='object')

# %%
#Reorganizing the columns using double brackets
organized_df = health_df[["locationabbr","year","locationdesc","topicdesc","measuredesc","submeasure","data_value","sample_size","gender","age","race","response","education", "geolocation"]]
organized_df.head()
# Out:
#   locationabbr  year locationdesc                      topicdesc  \
# 0           KS  2011       Kansas          Cigarette Use (Youth)
# 1           WY  1999      Wyoming          Cigarette Use (Youth)
# 2           DE  2009     Delaware          Cigarette Use (Youth)
# 3           WY  1995      Wyoming          Cigarette Use (Youth)
# 4           WY  2013      Wyoming  Smokeless Tobacco Use (Youth)
#
#       measuredesc                       submeasure data_value sample_size  \
# 0  Smoking Status            Ever Cigarette Smoker       39.5        1080
# 1  Smoking Status         Current Cigarette Smoker       34.6         747
# 2  Smoking Status         Current Cigarette Smoker        8.3        1791
# 3  Smoking Status        Frequent Cigarette Smoker       19.6         798
# 4     User Status  Frequent Smokeless Tobacco User        4.9        2183
#
#     gender       age       race  response      education  \
# 0  Overall  All Ages      White      Ever    High School
# 1     Male  All Ages  All Races   Current    High School
# 2   Female  All Ages  All Races   Current  Middle School
# 3   Female  All Ages  All Races  Frequent    High School
# 4  Overall  All Ages      White  Frequent    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-98.20078122...
# 1  {'type': 'Point', 'coordinates': [-108.1098303...
# 2  {'type': 'Point', 'coordinates': [-75.57774116...
# 3  {'type': 'Point', 'coordinates': [-108.1098303...
# 4  {'type': 'Point', 'coordinates': [-108.1098303...

# %% [markdown]
# ##### We Learned: Changing header names helped but we had to change them again, when we discovered confusion among team members

# %%
# Renaming column headers to assist in clarity
renamed_df = organized_df.rename(columns={"locationabbr":"Location Code","year":"Year","locationdesc":"State","topicdesc":"Use Type","measuredesc":"Status","submeasure":"Frequency","data_value":"% of Users","sample_size":"Sample Size","gender":"Gender","age":"Age","race":"Race","response":"User Status","education":"Education"})
renamed_df.head()
# Out:
#   Location Code  Year     State                       Use Type  \
# 0            KS  2011    Kansas          Cigarette Use (Youth)
# 1            WY  1999   Wyoming          Cigarette Use (Youth)
# 2            DE  2009  Delaware          Cigarette Use (Youth)
# 3            WY  1995   Wyoming          Cigarette Use (Youth)
# 4            WY  2013   Wyoming  Smokeless Tobacco Use (Youth)
#
#            Status                        Frequency % of Users Sample Size  \
# 0  Smoking Status            Ever Cigarette Smoker       39.5        1080
# 1  Smoking Status         Current Cigarette Smoker       34.6         747
# 2  Smoking Status         Current Cigarette Smoker        8.3        1791
# 3  Smoking Status        Frequent Cigarette Smoker       19.6         798
# 4     User Status  Frequent Smokeless Tobacco User        4.9        2183
#
#     Gender       Age       Race User Status      Education  \
# 0  Overall  All Ages      White        Ever    High School
# 1     Male  All Ages  All Races     Current    High School
# 2   Female  All Ages  All Races     Current  Middle School
# 3   Female  All Ages  All Races    Frequent    High School
# 4  Overall  All Ages      White    Frequent    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-98.20078122...
# 1  {'type': 'Point', 'coordinates': [-108.1098303...
# 2  {'type': 'Point', 'coordinates': [-75.57774116...
# 3  {'type': 'Point', 'coordinates': [-108.1098303...
# 4  {'type': 'Point', 'coordinates': [-108.1098303...

# %%
# Creating matching data to the dataset used in TED talk/ US data only used 
Minus_Nat= renamed_df.loc[renamed_df["State"] !="National (States and DC)"]
Minus_PR = Minus_Nat.loc[Minus_Nat["State"] !="Puerto Rico"]
Minus_NatPRGuam = Minus_PR.loc[Minus_PR["State"] !="Guam"]
Minus_NatPRGuam.head()
#Minus_Ohio['C'] = np.arange(len(Minus_Ohio))
#print (Minus_Ohio)
# Out:
#   Location Code  Year     State                       Use Type  \
# 0            KS  2011    Kansas          Cigarette Use (Youth)
# 1            WY  1999   Wyoming          Cigarette Use (Youth)
# 2            DE  2009  Delaware          Cigarette Use (Youth)
# 3            WY  1995   Wyoming          Cigarette Use (Youth)
# 4            WY  2013   Wyoming  Smokeless Tobacco Use (Youth)
#
#            Status                        Frequency % of Users Sample Size  \
# 0  Smoking Status            Ever Cigarette Smoker       39.5        1080
# 1  Smoking Status         Current Cigarette Smoker       34.6         747
# 2  Smoking Status         Current Cigarette Smoker        8.3        1791
# 3  Smoking Status        Frequent Cigarette Smoker       19.6         798
# 4     User Status  Frequent Smokeless Tobacco User        4.9        2183
#
#     Gender       Age       Race User Status      Education  \
# 0  Overall  All Ages      White        Ever    High School
# 1     Male  All Ages  All Races     Current    High School
# 2   Female  All Ages  All Races     Current  Middle School
# 3   Female  All Ages  All Races    Frequent    High School
# 4  Overall  All Ages      White    Frequent    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-98.20078122...
# 1  {'type': 'Point', 'coordinates': [-108.1098303...
# 2  {'type': 'Point', 'coordinates': [-75.57774116...
# 3  {'type': 'Point', 'coordinates': [-108.1098303...
# 4  {'type': 'Point', 'coordinates': [-108.1098303...

# %%
#cleansing data, dropping values not needed for our study
USA=Minus_NatPRGuam.dropna(how='any')
USA.head()
#USA.count()
# Out:
#   Location Code  Year     State                       Use Type  \
# 0            KS  2011    Kansas          Cigarette Use (Youth)
# 1            WY  1999   Wyoming          Cigarette Use (Youth)
# 2            DE  2009  Delaware          Cigarette Use (Youth)
# 3            WY  1995   Wyoming          Cigarette Use (Youth)
# 4            WY  2013   Wyoming  Smokeless Tobacco Use (Youth)
#
#            Status                        Frequency % of Users Sample Size  \
# 0  Smoking Status            Ever Cigarette Smoker       39.5        1080
# 1  Smoking Status         Current Cigarette Smoker       34.6         747
# 2  Smoking Status         Current Cigarette Smoker        8.3        1791
# 3  Smoking Status        Frequent Cigarette Smoker       19.6         798
# 4     User Status  Frequent Smokeless Tobacco User        4.9        2183
#
#     Gender       Age       Race User Status      Education  \
# 0  Overall  All Ages      White        Ever    High School
# 1     Male  All Ages  All Races     Current    High School
# 2   Female  All Ages  All Races     Current  Middle School
# 3   Female  All Ages  All Races    Frequent    High School
# 4  Overall  All Ages      White    Frequent    High School
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [-98.20078122...
# 1  {'type': 'Point', 'coordinates': [-108.1098303...
# 2  {'type': 'Point', 'coordinates': [-75.57774116...
# 3  {'type': 'Point', 'coordinates': [-108.1098303...
# 4  {'type': 'Point', 'coordinates': [-108.1098303...

# %% [markdown]
# #### We Learned:  Getting our data set to match the overall variables used in our comparison was not as easy as it originally seemed

# %%
# changing the percentage of users data to a usable integer float type 
USA[['% of Users']]=USA[['% of Users']].astype(float)

# %%
# Counts of states reporting for each year. To see any variance in reporting
USA_StateCount = USA.groupby('Year')['State'].nunique()
USA_StateCount
# Out:
# Year
# 1993    19
# 1995    21
# 1997    24
# 1999    20
# 2001    24
# 2003    32
# 2005    40
# 2007    41
# 2009    42
# 2011    43
# 2013    44
# 2015    38
# 2017    40
# Name: State, dtype: int64

# %%
# counts by use type validates number of reporting states 
USA_UseType_Count = USA.groupby('Use Type')['State'].nunique()
USA_UseType_Count
# Out:
# Use Type
# Any Tobacco Use (Youth)          39
# Cigar Use (Youth)                46
# Cigarette Use (Youth)            48
# E-Cigarette Use (Youth)          44
# Smokeless Tobacco Use (Youth)    48
# Name: State, dtype: int64

# %%
#Average percetage of users by year
USA_UsePercentage = USA.groupby('Year')['% of Users'].mean()
USA_UsePercentage
# Out:
# Year
# 1993    36.571579
# 1995    26.289634
# 1997    26.544444
# 1999    20.654296
# 2001    16.436196
# 2003    15.319567
# 2005    15.557080
# 2007    13.596225
# 2009    12.454654
# 2011    11.314208
# 2013     9.365586
# 2015    12.821463
# 2017     9.906269
# Name: % of Users, dtype: float64

# %%
# average use type by year
USA.groupby(['Year','Use Type']).mean()
# Out:
#                                     % of Users
# Year Use Type
# 1993 Cigarette Use (Youth)           36.571579
# 1995 Cigarette Use (Youth)           37.818543
#      Smokeless Tobacco Use (Youth)    7.964737
# 1997 Cigarette Use (Youth)           40.188418
#      Smokeless Tobacco Use (Youth)    6.419583
# 1999 Cigar Use (Youth)                8.987391
#      Cigarette Use (Youth)           37.033705
#      Smokeless Tobacco Use (Youth)    5.715888
# 2001 Cigar Use (Youth)                7.182986
#      Cigarette Use (Youth)           29.083162
#      Smokeless Tobacco Use (Youth)    5.091558
# 2003 Cigar Use (Youth)                6.960541
#      Cigarette Use (Youth)           27.418719
#      Smokeless Tobacco Use (Youth)    4.788670
# 2005 Cigar Use (Youth)                7.934974
#      Cigarette Use (Youth)           25.548877
#      Smokeless Tobacco Use (Youth)    5.510000
# 2007 Cigar Use (Youth)                6.962295
#      Cigarette Use (Youth)           22.263363
#      Smokeless Tobacco Use (Youth)    5.301095
# 2009 Cigar Use (Youth)                7.325085
#      Cigarette Use (Youth)           20.236209
#      Smokeless Tobacco Use (Youth)    5.496176
# 2011 Cigar Use (Youth)                6.521044
#      Cigarette Use (Youth)           18.236758
#      Smokeless Tobacco Use (Youth)    5.149143
# 2013 Cigar Use (Youth)                5.983978
#      Cigarette Use (Youth)           14.545278
#      Smokeless Tobacco Use (Youth)    4.888743
# 2015 Any Tobacco Use (Youth)         27.956631
#      Cigar Use (Youth)                5.226997
#      Cigarette Use (Youth)           12.529388
#      E-Cigarette Use (Youth)         18.820471
#      Smokeless Tobacco Use (Youth)    4.695000
# 2017 Any Tobacco Use (Youth)         18.160069
#      Cigar Use (Youth)                3.902896
#      Cigarette Use (Youth)            9.261398
#      E-Cigarette Use (Youth)         15.754225
#      Smokeless Tobacco Use (Youth)    3.351613

# %% [markdown]
# ### VISUAL 1: Percentage of Users by Gender Over Time

# %%
# Finding Average & Using GroupBy in order to separate the data into fields according to "Year and "Gender" values
grouped_usa_df = USA.groupby(['Year','Gender']).mean()

# %%
# Use unstack() to Plot all users response as a line chart
fig, ax = plt.subplots(figsize=(8,8))
grouped_usa_df.unstack().plot(ax=ax)
plt.title("% of Users By Gender Over Time", weight = 'bold')
plt.xlabel("Years", weight = 'bold')
plt.ylabel("Percentage (%) of Users", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL1.png")

plt.show()

# %% [markdown]
# ### VISUAL 2: Percentage of E-Cigarette Users by Gender Over Time

# %%
#Forming DataFrame for Just E-Cigarette User Responses over USA
USA_eCig=USA.loc[USA["Use Type"] ==("E-Cigarette Use (Youth)")]
USA_eCig.head()
# Out:
#     Location Code  Year           State                 Use Type       Status  \
# 41             NC  2015  North Carolina  E-Cigarette Use (Youth)  User Status
# 61             FL  2015         Florida  E-Cigarette Use (Youth)  User Status
# 89             NY  2015        New York  E-Cigarette Use (Youth)  User Status
# 107            VT  2015         Vermont  E-Cigarette Use (Youth)  User Status
# 133            VT  2015         Vermont  E-Cigarette Use (Youth)  User Status
#
#                      Frequency  % of Users Sample Size   Gender       Age  \
# 41       Ever E-Cigarette User        63.0         429  Overall  All Ages
# 61    Current E-Cigarette User         9.9        5752  Overall  All Ages
# 89   Frequent E-Cigarette User         4.8        2095  Overall  All Ages
# 107      Ever E-Cigarette User         7.4         362  Overall  All Ages
# 133  Frequent E-Cigarette User         0.8         365  Overall  All Ages
#
#                  Race User Status      Education  \
# 41      Multiple Race        Ever    High School
# 61          All Races     Current  Middle School
# 89              White    Frequent    High School
# 107  African American        Ever  Middle School
# 133  African American    Frequent  Middle School
#
#                                            geolocation
# 41   {'type': 'Point', 'coordinates': [-79.15925046...
# 61   {'type': 'Point', 'coordinates': [-81.92896053...
# 89   {'type': 'Point', 'coordinates': [-75.54397042...
# 107  {'type': 'Point', 'coordinates': [-72.51764079...
# 133  {'type': 'Point', 'coordinates': [-72.51764079...

# %%
# Finding Average & Using GroupBy in order to separate the data into fields according to "Year and "Gender" values
USA_eCig_Avg = USA_eCig.groupby(['Year','Gender']).mean()
USA_eCig_Avg.head()
# Out:
#               % of Users
# Year Gender
# 2015 Female    17.653285
#      Male      20.639416
#      Overall   18.693457
# 2017 Female    14.561842
#      Male      17.178947

# %% [markdown]
# #### We Learned:  That we could not find a consistent trend upward in E-Cigarette use, in the data we had available.

# %%
# Finding Average & Using GroupBy in order to separate the data into fields according to "Year and "Gender" values
USA_eCig_Avg = USA_eCig.groupby(['Year','Gender']).mean()

# %%
# Use unstack() to Plot the E-Cigarette users response as a line chart
fig, ax = plt.subplots(figsize=(8,8))
USA_eCig_Avg.unstack().plot(ax=ax)
plt.title("Percentage (%) of Users; E-Cigarettes By Gender Over Time", weight = 'bold')
plt.xlabel("Years", weight = 'bold')
plt.ylabel("Percentage (%) of E-Cigarette Users", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL2.png")

plt.show()

# %% [markdown]
# ### VISUAL 3: Percentage of Users by Ethnicity Over Time

# %%
# grouping the ethnicity by year
Grouped_USA_Ethinicity = USA.groupby(['Year','Race']).mean()

# %%
# Creating a LINE graph of ethnicity usage stats
fig, ax = plt.subplots(figsize=(15,15))
colors = ["black","pink","blue","red","tan","purple","orange","green"]
Grouped_USA_Ethinicity.unstack().plot.bar(ax=ax, color=colors)
plt.title("Percentage (%) of Teen Users Based on Ethnicity Over Time", weight = 'bold')
plt.xlabel("Years", weight = 'bold')
plt.ylabel("Average % of Cigarette Users Responses", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL3.png")

plt.show()

# %% [markdown]
# #### We Learned:  Although we enjoyed making all these graphs, many just didn't provide us with valuable information towards answering our questions.

# %% [markdown]
# ### VISUAL 4: Percentage of E-Cigarette Users by Ethnicity Over Time

# %%
# Grouping the ethnicity by year specific to E-Cig use
USA_eCig_Etinicity = USA_eCig.groupby(['Year','Race']).mean()

# %%
# Line graph of E-cig use only by ethnicity
fig, ax = plt.subplots(figsize=(10,10))
colors = ["black","pink","blue","red","tan","purple","orange","green"]
USA_eCig_Etinicity.unstack().plot.bar(ax=ax, color= colors)
plt.title("Percentage (%) of Teen E-Cigarette Users Based on Ethnicity from 2015-2017", weight = 'bold')
plt.xlabel("Years", weight = 'bold')
plt.ylabel("% Of E-Cigarette Users", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL4.png")

plt.show()

# %% [markdown]
# ### VISUAL 5: Percentage of Users by Use Status Over Time (Current, Ever, Frequent)

# %%
# grouping the data by year and user status
grouped_usa_User_Status = USA.groupby(['Year','User Status']).mean()

# %%
# graphing of % of users over time 
fig, ax = plt.subplots(figsize=(10,10))
grouped_usa_User_Status.unstack().plot.bar(ax=ax)
plt.title("Percentage (%) of Teen Smokers based on their Use Status Over Time", weight = 'bold')
plt.xlabel("Years", weight = 'bold')
plt.ylabel("% of Teen Smokers", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL5.png")

plt.show()

# %% [markdown]
# ### VISUAL 6: Percentage of E-Cigarette Users by Use Status Over Time (Current, Ever, Frequent)

# %%
# grouping for e-cig use only
E_Cig_grouped_usa_User_Status = USA_eCig.groupby(['Year','User Status']).mean()

# %%
# graphing of % of users over time for e-cig only
fig, ax = plt.subplots(figsize=(10,10))
E_Cig_grouped_usa_User_Status.unstack().plot.bar(ax=ax)
plt.title("Percentage (%) of Teen E-Cigarette Users Based on User Status from 2015-2017", weight = 'bold')
plt.xlabel("Years", weight = 'bold')
plt.ylabel("% of Teen E-Cigarette Users", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL6.png")

plt.show()

# %% [markdown]
# ### VISUAL 7: Percentage of  E-cigarette Users by All Use Type (2015 - 2017)

# %%
#Forming DataFrame for Just E-Cigarette User Responses over USA
USA_Use_type_grp=USA.groupby(['Year','Use Type']).mean()
USA_Use_type_grp.head()
# Out:
#                                     % of Users
# Year Use Type
# 1993 Cigarette Use (Youth)           36.571579
# 1995 Cigarette Use (Youth)           37.818543
#      Smokeless Tobacco Use (Youth)    7.964737
# 1997 Cigarette Use (Youth)           40.188418
#      Smokeless Tobacco Use (Youth)    6.419583

# %%
# GRAPH
fig, ax = plt.subplots(figsize=(10,10))
USA_Use_type_grp.unstack().plot.bar(ax=ax)
plt.title("Percentage (%) of Teen Users Based on User Type from 2015-2017", weight = 'bold')
plt.xlabel("Years", weight = 'bold')
plt.ylabel("Percentage (%) of Users", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL7.png")

plt.show()

# %% [markdown]
# #### We Learned:  That sometimes graphs showed us what we already suspected, that changes in variables monitored over time added noise to our data making comparisons difficult

# %% [markdown]
# ###### Reframing of Data for Additional Analysis

# %%
# redefining qualitative value of users
Avg_USA=USA[['% of Users']]=USA[['% of Users']].astype(float)

# %%
# Reframing data 
National= renamed_df.loc[renamed_df["State"] =="National (States and DC)"]
National.head()
# Out:
#       Location Code  Year                     State  \
# 20991            US  2017  National (States and DC)
# 21054            US  2017  National (States and DC)
# 21076            US  2017  National (States and DC)
# 21120            US  2017  National (States and DC)
# 21166            US  2017  National (States and DC)
#
#                             Use Type          Status  \
# 20991          Cigarette Use (Youth)  Smoking Status
# 21054  Smokeless Tobacco Use (Youth)     User Status
# 21076  Smokeless Tobacco Use (Youth)     User Status
# 21120              Cigar Use (Youth)  Smoking Status
# 21166          Cigarette Use (Youth)  Smoking Status
#
#                              Frequency % of Users Sample Size   Gender  \
# 20991         Current Cigarette Smoker        7.8        7389   Female
# 21054  Frequent Smokeless Tobacco User        0.4         638  Overall
# 21076   Current Smokeless Tobacco User        3.5        2737  Overall
# 21120            Frequent Cigar Smoker        1.1        3536  Overall
# 21166        Frequent Cigarette Smoker        0.3         633  Overall
#
#             Age              Race User Status    Education  \
# 20991  All Ages         All Races     Current  High School
# 21054  All Ages             Asian    Frequent  High School
# 21076  All Ages  African American     Current  High School
# 21120  All Ages          Hispanic    Frequent  High School
# 21166  All Ages             Asian    Frequent  High School
#
#                                              geolocation
# 20991  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21054  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21076  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21120  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21166  {'type': 'Point', 'coordinates': [-95.712891, ...

# %%
# Dropping null values - Survey had values listed as null for those of statistical insignificance in the response value.
no_null_National =National.dropna(how='any')
no_null_National.head()
# Out:
#       Location Code  Year                     State  \
# 20991            US  2017  National (States and DC)
# 21054            US  2017  National (States and DC)
# 21076            US  2017  National (States and DC)
# 21120            US  2017  National (States and DC)
# 21166            US  2017  National (States and DC)
#
#                             Use Type          Status  \
# 20991          Cigarette Use (Youth)  Smoking Status
# 21054  Smokeless Tobacco Use (Youth)     User Status
# 21076  Smokeless Tobacco Use (Youth)     User Status
# 21120              Cigar Use (Youth)  Smoking Status
# 21166          Cigarette Use (Youth)  Smoking Status
#
#                              Frequency % of Users Sample Size   Gender  \
# 20991         Current Cigarette Smoker        7.8        7389   Female
# 21054  Frequent Smokeless Tobacco User        0.4         638  Overall
# 21076   Current Smokeless Tobacco User        3.5        2737  Overall
# 21120            Frequent Cigar Smoker        1.1        3536  Overall
# 21166        Frequent Cigarette Smoker        0.3         633  Overall
#
#             Age              Race User Status    Education  \
# 20991  All Ages         All Races     Current  High School
# 21054  All Ages             Asian    Frequent  High School
# 21076  All Ages  African American     Current  High School
# 21120  All Ages          Hispanic    Frequent  High School
# 21166  All Ages             Asian    Frequent  High School
#
#                                              geolocation
# 20991  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21054  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21076  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21120  {'type': 'Point', 'coordinates': [-95.712891, ...
# 21166  {'type': 'Point', 'coordinates': [-95.712891, ...

# %%
# Reframing for Ohio data only (Originally to compare Ohio e-use to US e-use, but No Ohio reporting on e-use!)
Ohio_df= renamed_df.loc[renamed_df["State"] =="Ohio"]
Ohio_df.head()
# Out:
#     Location Code  Year State                       Use Type          Status  \
# 8              OH  2013  Ohio          Cigarette Use (Youth)  Smoking Status
# 23             OH  2011  Ohio  Smokeless Tobacco Use (Youth)     User Status
# 49             OH  2007  Ohio  Smokeless Tobacco Use (Youth)     User Status
# 99             OH  2011  Ohio          Cigarette Use (Youth)  Smoking Status
# 142            OH  2013  Ohio          Cigarette Use (Youth)  Smoking Status
#
#                            Frequency % of Users Sample Size   Gender  \
# 8          Frequent Cigarette Smoker        NaN         NaN  Overall
# 23   Frequent Smokeless Tobacco User        NaN         NaN  Overall
# 49    Current Smokeless Tobacco User        9.8        2498  Overall
# 99             Ever Cigarette Smoker       40.7         358  Overall
# 142        Frequent Cigarette Smoker        3.2         329  Overall
#
#           Age              Race User Status    Education  \
# 8    All Ages             Asian    Frequent  High School
# 23   All Ages     Multiple Race    Frequent  High School
# 49   All Ages         All Races     Current  High School
# 99   All Ages  African American        Ever  High School
# 142  All Ages  African American    Frequent  High School
#
#                                            geolocation
# 8    {'type': 'Point', 'coordinates': [-82.40426005...
# 23   {'type': 'Point', 'coordinates': [-82.40426005...
# 49   {'type': 'Point', 'coordinates': [-82.40426005...
# 99   {'type': 'Point', 'coordinates': [-82.40426005...
# 142  {'type': 'Point', 'coordinates': [-82.40426005...

# %%
#removal of null values for Ohio
no_null_OH =Ohio_df.dropna(how='any')
no_null_OH.head()
# Out:
#     Location Code  Year State                       Use Type          Status  \
# 49             OH  2007  Ohio  Smokeless Tobacco Use (Youth)     User Status
# 99             OH  2011  Ohio          Cigarette Use (Youth)  Smoking Status
# 142            OH  2013  Ohio          Cigarette Use (Youth)  Smoking Status
# 224            OH  2011  Ohio          Cigarette Use (Youth)  Smoking Status
# 460            OH  2011  Ohio  Smokeless Tobacco Use (Youth)     User Status
#
#                            Frequency % of Users Sample Size   Gender  \
# 49    Current Smokeless Tobacco User        9.8        2498  Overall
# 99             Ever Cigarette Smoker       40.7         358  Overall
# 142        Frequent Cigarette Smoker        3.2         329  Overall
# 224            Ever Cigarette Smoker       50.3         667   Female
# 460  Frequent Smokeless Tobacco User          0         375  Overall
#
#           Age              Race User Status    Education  \
# 49   All Ages         All Races     Current  High School
# 99   All Ages  African American        Ever  High School
# 142  All Ages  African American    Frequent  High School
# 224  All Ages         All Races        Ever  High School
# 460  All Ages  African American    Frequent  High School
#
#                                            geolocation
# 49   {'type': 'Point', 'coordinates': [-82.40426005...
# 99   {'type': 'Point', 'coordinates': [-82.40426005...
# 142  {'type': 'Point', 'coordinates': [-82.40426005...
# 224  {'type': 'Point', 'coordinates': [-82.40426005...
# 460  {'type': 'Point', 'coordinates': [-82.40426005...

# %%
#validating variable types
no_null_National.dtypes
# Out:
# Location Code    object
# Year             object
# State            object
# Use Type         object
# Status           object
# Frequency        object
# % of Users       object
# Sample Size      object
# Gender           object
# Age              object
# Race             object
# User Status      object
# Education        object
# geolocation      object
# dtype: object

# %%
#no_null_State.t0 float
no_null_National[['% of Users']]=no_null_National[['% of Users']].astype(float)

# %%
#redifining percentage as float for no-null ohio
no_null_OH[['% of Users']]=no_null_OH[['% of Users']].astype(float)

# %%
# validating type
no_null_OH.dtypes
# Out:
# Location Code     object
# Year              object
# State             object
# Use Type          object
# Status            object
# Frequency         object
# % of Users       float64
# Sample Size       object
# Gender            object
# Age               object
# Race              object
# User Status       object
# Education         object
# geolocation       object
# dtype: object

# %%
# validating types
no_null_National.dtypes
# Out:
# Location Code     object
# Year              object
# State             object
# Use Type          object
# Status            object
# Frequency         object
# % of Users       float64
# Sample Size       object
# Gender            object
# Age               object
# Race              object
# User Status       object
# Education         object
# geolocation       object
# dtype: object

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_OH_df = no_null_OH.groupby(['Location Code','Year','Use Type','Status','Frequency','Gender','Age','Race','Education'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_OH_df)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000196889CEB70>

# %%
# Grouping for comparison of OHIO to US - later discovered no reporting values for e-cig use meant we didn't use. 
grouped_OH_comparison = grouped_OH_df.mean()
grouped_OH_comparison
# Out:
#                                                                                                                                                % of Users
# Location Code Year Use Type                      Status         Frequency                       Gender  Age      Race             Education
# OH            1993 Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School        29.0
#                                                                                                 Male    All Ages All Races        High School        30.4
#                                                                                                 Overall All Ages African American High School        14.2
#                                                                                                                  All Races        High School        29.7
#                                                                                                                  White            High School        32.8
#                                                                 Ever Cigarette Smoker           Female  All Ages All Races        High School        66.0
#                                                                                                 Male    All Ages All Races        High School        71.0
#                                                                                                 Overall All Ages African American High School        65.1
#                                                                                                                  All Races        High School        68.6
#                                                                                                                  White            High School        68.8
#                                                                 Frequent Cigarette Smoker       Female  All Ages All Races        High School        12.3
#                                                                                                 Male    All Ages All Races        High School        16.1
#                                                                                                 Overall All Ages African American High School         3.3
#                                                                                                                  All Races        High School        14.3
#                                                                                                                  White            High School        16.6
#               1997 Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School        32.0
#                                                                                                 Male    All Ages All Races        High School        36.9
#                                                                                                 Overall All Ages African American High School        19.6
#                                                                                                                  All Races        High School        34.5
#                                                                                                                  White            High School        38.1
#                                                                 Ever Cigarette Smoker           Female  All Ages All Races        High School        67.8
#                                                                                                 Male    All Ages All Races        High School        70.5
#                                                                                                 Overall All Ages African American High School        67.3
#                                                                                                                  All Races        High School        69.2
#                                                                                                                  White            High School        69.0
#                                                                 Frequent Cigarette Smoker       Female  All Ages All Races        High School        16.4
#                                                                                                 Male    All Ages All Races        High School        19.7
#                                                                                                 Overall All Ages African American High School         6.4
#                                                                                                                  All Races        High School        18.2
#                                                                                                                  White            High School        20.5
# ...                                                                                                                                                   ...
#               2013 Cigar Use (Youth)             Smoking Status Current Cigar Smoker            Overall All Ages African American High School        11.5
#                                                                                                                  All Races        High School        11.5
#                                                                                                                  White            High School        11.6
#                                                                 Frequent Cigar Smoker           Female  All Ages All Races        High School         0.6
#                                                                                                 Male    All Ages All Races        High School         2.3
#                                                                                                 Overall All Ages African American High School         2.3
#                                                                                                                  All Races        High School         1.4
#                                                                                                                  White            High School         1.2
#                    Cigarette Use (Youth)         Smoking Status Current Cigarette Smoker        Female  All Ages All Races        High School        13.4
#                                                                                                 Male    All Ages All Races        High School        16.7
#                                                                                                 Overall All Ages African American High School         9.8
#                                                                                                                  All Races        High School        15.1
#                                                                                                                  Hispanic         High School        24.9
#                                                                                                                  White            High School        15.9
#                                                                 Frequent Cigarette Smoker       Female  All Ages All Races        High School         5.1
#                                                                                                 Male    All Ages All Races        High School         8.3
#                                                                                                 Overall All Ages African American High School         3.2
#                                                                                                                  All Races        High School         6.8
#                                                                                                                  Hispanic         High School        10.6
#                                                                                                                  White            High School         7.3
#                    Smokeless Tobacco Use (Youth) User Status    Current Smokeless Tobacco User  Female  All Ages All Races        High School         1.9
#                                                                                                 Male    All Ages All Races        High School        15.1
#                                                                                                 Overall All Ages African American High School         6.1
#                                                                                                                  All Races        High School         8.6
#                                                                                                                  White            High School         9.1
#                                                                 Frequent Smokeless Tobacco User Female  All Ages All Races        High School         0.2
#                                                                                                 Male    All Ages All Races        High School         5.7
#                                                                                                 Overall All Ages African American High School         0.7
#                                                                                                                  All Races        High School         3.0
#                                                                                                                  White            High School         3.5
#
# [227 rows x 1 columns]

# %%
# Regrouping of data for Lat / long values for heat maps
latlon = (pd.concat({i: json_normalize(x) for i, x in USA.pop('geolocation').items()})
         .reset_index(level=1, drop=True)
         .join(USA)
         .reset_index(drop=True))
latlon.head()
# Out:
#                       coordinates   type Location Code  Year     State  \
# 0     [-98.200781227, 38.3477403]  Point            KS  2011    Kansas
# 1  [-108.109830353, 43.235541343]  Point            WY  1999   Wyoming
# 2   [-75.577741168, 39.008830667]  Point            DE  2009  Delaware
# 3  [-108.109830353, 43.235541343]  Point            WY  1995   Wyoming
# 4  [-108.109830353, 43.235541343]  Point            WY  2013   Wyoming
#
#                         Use Type          Status  \
# 0          Cigarette Use (Youth)  Smoking Status
# 1          Cigarette Use (Youth)  Smoking Status
# 2          Cigarette Use (Youth)  Smoking Status
# 3          Cigarette Use (Youth)  Smoking Status
# 4  Smokeless Tobacco Use (Youth)     User Status
#
#                          Frequency  % of Users Sample Size   Gender       Age  \
# 0            Ever Cigarette Smoker        39.5        1080  Overall  All Ages
# 1         Current Cigarette Smoker        34.6         747     Male  All Ages
# 2         Current Cigarette Smoker         8.3        1791   Female  All Ages
# 3        Frequent Cigarette Smoker        19.6         798   Female  All Ages
# 4  Frequent Smokeless Tobacco User         4.9        2183  Overall  All Ages
#
#         Race User Status      Education
# 0      White        Ever    High School
# 1  All Races     Current    High School
# 2  All Races     Current  Middle School
# 3  All Races    Frequent    High School
# 4      White    Frequent    High School

# %%
# heat map reframing and validation
latlon2 = pd.DataFrame(latlon["coordinates"].values.tolist())
latlon2.head()
# Out:
#             0          1
# 0  -98.200781  38.347740
# 1 -108.109830  43.235541
# 2  -75.577741  39.008831
# 3 -108.109830  43.235541
# 4 -108.109830  43.235541

# %%
#Lat long renaming for heat maps
renamedlatlon = latlon2.rename(columns={0:"Lon",1:"Lat"})
renamedlatlon.head()
# Out:
#           Lon        Lat
# 0  -98.200781  38.347740
# 1 -108.109830  43.235541
# 2  -75.577741  39.008831
# 3 -108.109830  43.235541
# 4 -108.109830  43.235541

# %%
# merged lat long for creating heat maps
mergedlatlon = pd.merge(latlon, renamedlatlon, left_index=True, right_index=True, how='inner')
mergedlatlon
# Out:
#                              coordinates   type Location Code  Year  \
# 0            [-98.200781227, 38.3477403]  Point            KS  2011
# 1         [-108.109830353, 43.235541343]  Point            WY  1999
# 2          [-75.577741168, 39.008830667]  Point            DE  2009
# 3         [-108.109830353, 43.235541343]  Point            WY  1995
# 4         [-108.109830353, 43.235541343]  Point            WY  2013
# 5          [-89.538030825, 32.745510099]  Point            MS  2001
# 6          [-72.517640791, 43.625381239]  Point            VT  2005
# 7         [-109.424420645, 47.066528972]  Point            MT  2005
# 8         [-114.363730042, 43.682630005]  Point            ID  2013
# 9         [-106.240580985, 34.520880952]  Point            NM  2005
# 10      [-68.985031336, 45.254228894001]  Point            ME  2015
# 11         [-80.712640135, 38.665510202]  Point            WV  2009
# 12         [-75.577741168, 39.008830667]  Point            DE  2013
# 13        [-114.363730042, 43.682630005]  Point            ID  2005
# 14         [-81.045371207, 33.998821303]  Point            SC  2015
# 5         Mississippi          Cigarette Use (Youth)  Smoking Status
# 6             Vermont  Smokeless Tobacco Use (Youth)     User Status
# 7             Montana          Cigarette Use (Youth)  Smoking Status
# 8               Idaho              Cigar Use (Youth)  Smoking Status
# 9          New Mexico  Smokeless Tobacco Use (Youth)     User Status
# 10              Maine        Any Tobacco Use (Youth)     User Status
# 11      West Virginia              Cigar Use (Youth)  Smoking Status
# 12           Delaware  Smokeless Tobacco Use (Youth)     User Status
# 13              Idaho          Cigarette Use (Youth)  Smoking Status
# 14     South Carolina          Cigarette Use (Youth)  Smoking Status
# 15      Massachusetts              Cigar Use (Youth)  Smoking Status
# 16            Vermont              Cigar Use (Youth)  Smoking Status
# 17      New Hampshire          Cigarette Use (Youth)  Smoking Status
# 18       North Dakota          Cigarette Use (Youth)  Smoking Status
# 19           Delaware              Cigar Use (Youth)  Smoking Status
# 20            Montana          Cigarette Use (Youth)  Smoking Status
# 21          Louisiana          Cigarette Use (Youth)  Smoking Status
# 22           Delaware          Cigarette Use (Youth)  Smoking Status
# 23      West Virginia  Smokeless Tobacco Use (Youth)     User Status
# 24      New Hampshire          Cigarette Use (Youth)  Smoking Status
# 25           Delaware        Any Tobacco Use (Youth)     User Status
# 26      West Virginia          Cigarette Use (Youth)  Smoking Status
# 27           Arkansas  Smokeless Tobacco Use (Youth)     User Status
# 28       South Dakota  Smokeless Tobacco Use (Youth)     User Status
# 29     North Carolina        E-Cigarette Use (Youth)     User Status
# ...               ...                            ...             ...
# 22614      New Mexico          Cigarette Use (Youth)  Smoking Status
# 22615    Pennsylvania              Cigar Use (Youth)  Smoking Status
# 22616    South Dakota          Cigarette Use (Youth)  Smoking Status
# 22617   Massachusetts              Cigar Use (Youth)  Smoking Status
# 22618        Nebraska          Cigarette Use (Youth)  Smoking Status
# 22619          Alaska          Cigarette Use (Youth)  Smoking Status
# 22620         Vermont  Smokeless Tobacco Use (Youth)     User Status
# 22621          Alaska          Cigarette Use (Youth)  Smoking Status
# 22622        Kentucky          Cigarette Use (Youth)  Smoking Status
# 22623        Arkansas          Cigarette Use (Youth)  Smoking Status
# 22624          Nevada  Smokeless Tobacco Use (Youth)     User Status
# 22625          Hawaii          Cigarette Use (Youth)  Smoking Status
# 22626     Connecticut          Cigarette Use (Youth)  Smoking Status
# 22627    Rhode Island  Smokeless Tobacco Use (Youth)     User Status
# 22628        New York          Cigarette Use (Youth)  Smoking Status
# 22629         Indiana          Cigarette Use (Youth)  Smoking Status
# 22630       Tennessee              Cigar Use (Youth)  Smoking Status
# 22631          Kansas  Smokeless Tobacco Use (Youth)     User Status
# 22632         Florida          Cigarette Use (Youth)  Smoking Status
# 22633   Massachusetts  Smokeless Tobacco Use (Youth)     User Status
# 22634        Delaware  Smokeless Tobacco Use (Youth)     User Status
# 22635    Rhode Island  Smokeless Tobacco Use (Youth)     User Status
# 22636        Maryland  Smokeless Tobacco Use (Youth)     User Status
# 22637         Georgia              Cigar Use (Youth)  Smoking Status
# 22638         Vermont              Cigar Use (Youth)  Smoking Status
# 22639    Rhode Island        E-Cigarette Use (Youth)     User Status
# 22640        Oklahoma              Cigar Use (Youth)  Smoking Status
# 22641        New York  Smokeless Tobacco Use (Youth)     User Status
# 22642  South Carolina              Cigar Use (Youth)  Smoking Status
# 22643        Delaware  Smokeless Tobacco Use (Youth)     User Status
#
#                              Frequency  % of Users Sample Size   Gender  \
# 0                Ever Cigarette Smoker        39.5        1080  Overall
# 1             Current Cigarette Smoker        34.6         747     Male
# 2             Current Cigarette Smoker         8.3        1791   Female
# 3            Frequent Cigarette Smoker        19.6         798   Female
# 4      Frequent Smokeless Tobacco User         4.9        2183  Overall
# 5             Current Cigarette Smoker        14.3         808  Overall
# 6       Current Smokeless Tobacco User        20.8         127  Overall
# 7                Ever Cigarette Smoker        70.3         109  Overall
# 8                 Current Cigar Smoker         8.2        1360  Overall
# 9      Frequent Smokeless Tobacco User         3.3        2647     Male
# 10                Current Tobacco User        19.2         324  Overall
# 11               Frequent Cigar Smoker         0.8         978   Female
# 12     Frequent Smokeless Tobacco User         0.2        1491  Overall
# 13               Ever Cigarette Smoker        41.2         739   Female
# 14           Frequent Cigarette Smoker         2.6         655   Female
# 15               Frequent Cigar Smoker         1.1        1766  Overall
# 16               Frequent Cigar Smoker         1.0         637  Overall
# 17           Frequent Cigarette Smoker         0.9         409  Overall
# 18               Ever Cigarette Smoker        18.8        1532  Overall
# 19                Current Cigar Smoker        13.4         131  Overall
# 20            Current Cigarette Smoker        30.7        2424  Overall
# 21           Frequent Cigarette Smoker         5.1         566   Female
# 22            Current Cigarette Smoker        12.7         124  Overall
# 23     Frequent Smokeless Tobacco User         0.4        1069   Female
# 24           Frequent Cigarette Smoker        18.8        1897  Overall
# 25                Current Tobacco User        12.6         604  Overall
# 26           Frequent Cigarette Smoker        14.6         653     Male
# 27      Current Smokeless Tobacco User        13.8        1974  Overall
# 28      Current Smokeless Tobacco User        16.9         659     Male
# 29               Ever E-Cigarette User        63.0         429  Overall
# ...                                ...         ...         ...      ...
# 22614         Current Cigarette Smoker        11.4         298  Overall
# 22615            Frequent Cigar Smoker         0.8        2072  Overall
# 22616            Ever Cigarette Smoker        76.4         767     Male
# 22617            Frequent Cigar Smoker         2.3         214  Overall
# 22618        Frequent Cigarette Smoker         3.6         811   Female
# 22619            Ever Cigarette Smoker        43.7         115  Overall
# 22620   Current Smokeless Tobacco User        19.4         101  Overall
# 22621         Current Cigarette Smoker        15.9         620     Male
# 22622        Frequent Cigarette Smoker         1.8        1650  Overall
# 22623         Current Cigarette Smoker        23.9         969  Overall
# 22624   Current Smokeless Tobacco User         6.1         878     Male
# 22625        Frequent Cigarette Smoker         0.9        4972  Overall
# 22626         Current Cigarette Smoker        14.8        1504  Overall
# 22627   Current Smokeless Tobacco User         0.8         271  Overall
# 22628         Current Cigarette Smoker        20.4         138  Overall
# 22629        Frequent Cigarette Smoker        10.4        1185   Female
# 22630             Current Cigar Smoker        13.5        1968     Male
# 22631  Frequent Smokeless Tobacco User         2.6        1324  Overall
# 22632        Frequent Cigarette Smoker         3.8        3029     Male
# 22633  Frequent Smokeless Tobacco User         0.8        3100  Overall
# 22634  Frequent Smokeless Tobacco User         1.3        1023     Male
# 22635  Frequent Smokeless Tobacco User         1.0         114  Overall
# 22636   Current Smokeless Tobacco User         5.1         637  Overall
# 22637            Frequent Cigar Smoker         1.6         735  Overall
# 22638            Frequent Cigar Smoker         0.7       10217   Female
# 22639            Ever E-Cigarette User        17.2        1221     Male
# 22640            Frequent Cigar Smoker         3.1         128  Overall
# 22641  Frequent Smokeless Tobacco User         1.4         700  Overall
# 22642            Frequent Cigar Smoker         0.2         694   Female
# 22643   Current Smokeless Tobacco User         5.1        2684  Overall
#
#             Age                           Race User Status      Education  \
# 0      All Ages                          White        Ever    High School
# 1      All Ages                      All Races     Current    High School
# 2      All Ages                      All Races     Current  Middle School
# 3      All Ages                      All Races    Frequent    High School
# 4      All Ages                          White    Frequent    High School
# 5      All Ages               African American     Current  Middle School
# 6      All Ages               African American     Current    High School
# 7      All Ages                       Hispanic        Ever    High School
# 8      All Ages                          White     Current    High School
# 9      All Ages                      All Races    Frequent    High School
# 10     All Ages                          Asian     Current    High School
# 11     All Ages                      All Races    Frequent  Middle School
# 12     All Ages                          White    Frequent  Middle School
# 13     All Ages                      All Races        Ever    High School
# 14     All Ages                      All Races    Frequent    High School
# 15     All Ages                          White    Frequent    High School
# 16     All Ages                          Asian    Frequent    High School
# 17     All Ages                          Asian    Frequent    High School
# 18     All Ages                          White        Ever  Middle School
# 19     All Ages                  Multiple Race     Current    High School
# 20     All Ages                      All Races     Current    High School
# 21     All Ages                      All Races    Frequent    High School
# 22     All Ages                  Multiple Race     Current    High School
# 23     All Ages                      All Races    Frequent  Middle School
# 24     All Ages                          White    Frequent    High School
# 25     All Ages               African American     Current  Middle School
# 26     All Ages                      All Races    Frequent    High School
# 27     All Ages                      All Races     Current    High School
# 28     All Ages                      All Races     Current    High School
# 29     All Ages                  Multiple Race        Ever    High School
# ...         ...                            ...         ...            ...
# 22614  All Ages  American Indian/Alaska Native     Current  Middle School
# 22615  All Ages                      All Races    Frequent    High School
# 22616  All Ages                      All Races        Ever    High School
# 22617  All Ages                          Asian    Frequent    High School
# 22618  All Ages                      All Races    Frequent    High School
# 22619  All Ages                  Multiple Race        Ever    High School
# 22620  All Ages                       Hispanic     Current    High School
# 22621  All Ages                      All Races     Current    High School
# 22622  All Ages                      All Races    Frequent  Middle School
# 22623  All Ages                          White     Current    High School
# 22624  All Ages                      All Races     Current    High School
# 22625  All Ages                      All Races    Frequent  Middle School
# 22626  All Ages                          White     Current    High School
# 22627  All Ages               African American     Current  Middle School
# 22628  All Ages               Pacific Islander     Current    High School
# 22629  All Ages                      All Races    Frequent    High School
# 22630  All Ages                      All Races     Current    High School
# 22631  All Ages                          White    Frequent    High School
# 22632  All Ages                      All Races    Frequent    High School
# 22633  All Ages                          White    Frequent    High School
# 22634  All Ages                      All Races    Frequent    High School
# 22635  All Ages                          Asian    Frequent  Middle School
# 22636  All Ages                          White     Current    High School
# 22637  All Ages               African American    Frequent    High School
# 22638  All Ages                      All Races    Frequent    High School
# 22639  All Ages                      All Races        Ever  Middle School
# 22640  All Ages                       Hispanic    Frequent    High School
# 22641  All Ages                          Asian    Frequent    High School
# 22642  All Ages                      All Races    Frequent    High School
# 22643  All Ages                      All Races     Current    High School
#
#               Lon        Lat
# 0      -98.200781  38.347740
# 1     -108.109830  43.235541
# 2      -75.577741  39.008831
# 3     -108.109830  43.235541
# 4     -108.109830  43.235541
# 5      -89.538031  32.745510
# 6      -72.517641  43.625381
# 7     -109.424421  47.066529
# 8     -114.363730  43.682630
# 9     -106.240581  34.520881
# 10     -68.985031  45.254229
# 11     -80.712640  38.665510
# 12     -75.577741  39.008831
# 13    -114.363730  43.682630
# 14     -81.045371  33.998821
# 15     -72.082691  42.276870
# 16     -72.517641  43.625381
# 17     -71.500361  43.655950
# 18    -100.118421  47.475320
# 19     -75.577741  39.008831
# 20    -109.424421  47.066529
# 21     -92.445680  31.312661
# 22     -75.577741  39.008831
# 23     -80.712640  38.665510
# 24     -71.500361  43.655950
# 25     -75.577741  39.008831
# 26     -80.712640  38.665510
# 27     -92.274491  34.748650
# 28    -100.373531  44.353130
# 29     -79.159250  35.466221
# ...           ...        ...
# 22614 -106.240581  34.520881
# 22615  -77.860700  40.793730
# 22616 -100.373531  44.353130
# 22617  -72.082691  42.276870
# 22618  -99.365721  41.641041
# 22619 -147.722059  64.845080
# 22620  -72.517641  43.625381
# 22621 -147.722059  64.845080
# 22622  -84.774971  37.645970
# 22623  -92.274491  34.748650
# 22624 -117.071841  39.493240
# 22625 -157.857749  21.304850
# 22626  -72.649841  41.562661
# 22627  -71.522470  41.708280
# 22628  -75.543970  42.827001
# 22629  -86.149960  39.766910
# 22630  -85.774491  35.680941
# 22631  -98.200781  38.347740
# 22632  -81.928961  28.932040
# 22633  -72.082691  42.276870
# 22634  -75.577741  39.008831
# 22635  -71.522470  41.708280
# 22636  -76.609260  39.290581
# 22637  -83.627580  32.839681
# 22638  -72.517641  43.625381
# 22639  -71.522470  41.708280
# 22640  -97.521070  35.472031
# 22641  -75.543970  42.827001
# 22642  -81.045371  33.998821
# 22643  -75.577741  39.008831
#
# [22644 rows x 17 columns]

# %%
# Heat map tables 
ECig_df= mergedlatlon.loc[mergedlatlon["Use Type"] =="E-Cigarette Use (Youth)"]
ECig_Gender = ECig_df.loc[ECig_df["Gender"] =="Overall"]
ECig_Race = ECig_Gender.loc[ECig_Gender["Race"] =="All Races"]
ECig_User = ECig_Race.loc[ECig_Race["Frequency"] =="Current E-Cigarette User"]
ECig_2017 = ECig_User.loc[ECig_User["Year"] =="2017"]
ECig_2017
# Out:
#                              coordinates   type Location Code  Year  \
# 12806       [-85.774490914, 35.68094058]  Point            TN  2017
# 12812      [-78.457890463, 37.542680674]  Point            VA  2017
# 12883      [-80.712640135, 38.665510202]  Point            WV  2017
# 13000   [-99.365720623, 41.641040988001]  Point            NE  2017
# 13030      [-76.609260111, 39.290580964]  Point            MD  2017
# 13048      [-75.577741168, 39.008830667]  Point            DE  2017
# 13030              Maryland  E-Cigarette Use (Youth)  User Status
# 13048              Delaware  E-Cigarette Use (Youth)  User Status
# 13083            New Mexico  E-Cigarette Use (Youth)  User Status
# 13182            California  E-Cigarette Use (Youth)  User Status
# 13222             Wisconsin  E-Cigarette Use (Youth)  User Status
# 13256                Alaska  E-Cigarette Use (Youth)  User Status
# 13276              Missouri  E-Cigarette Use (Youth)  User Status
# 13352         West Virginia  E-Cigarette Use (Youth)  User Status
# 13599                 Idaho  E-Cigarette Use (Youth)  User Status
# 13768               Montana  E-Cigarette Use (Youth)  User Status
# 13799                  Utah  E-Cigarette Use (Youth)  User Status
# 13805                Nevada  E-Cigarette Use (Youth)  User Status
# 13848          North Dakota  E-Cigarette Use (Youth)  User Status
# 13857          North Dakota  E-Cigarette Use (Youth)  User Status
# 13871              Delaware  E-Cigarette Use (Youth)  User Status
# 14006                Nevada  E-Cigarette Use (Youth)  User Status
# 14078               Florida  E-Cigarette Use (Youth)  User Status
# 14127              Kentucky  E-Cigarette Use (Youth)  User Status
# 14149                Hawaii  E-Cigarette Use (Youth)  User Status
# 14158                 Texas  E-Cigarette Use (Youth)  User Status
# 14269                Hawaii  E-Cigarette Use (Youth)  User Status
# 14324              Maryland  E-Cigarette Use (Youth)  User Status
# 14390        North Carolina  E-Cigarette Use (Youth)  User Status
# 14427        South Carolina  E-Cigarette Use (Youth)  User Status
# 14433          Rhode Island  E-Cigarette Use (Youth)  User Status
# 14514  District of Columbia  E-Cigarette Use (Youth)  User Status
# 14585              Oklahoma  E-Cigarette Use (Youth)  User Status
# 14591               Vermont  E-Cigarette Use (Youth)  User Status
# 14731                 Maine  E-Cigarette Use (Youth)  User Status
# 14834              Michigan  E-Cigarette Use (Youth)  User Status
# 14993               Vermont  E-Cigarette Use (Youth)  User Status
# 15085                Kansas  E-Cigarette Use (Youth)  User Status
# 15187              Kentucky  E-Cigarette Use (Youth)  User Status
# 15234          Pennsylvania  E-Cigarette Use (Youth)  User Status
# 15244              Arkansas  E-Cigarette Use (Youth)  User Status
# 19623               Arizona  E-Cigarette Use (Youth)  User Status
# 19682                  Iowa  E-Cigarette Use (Youth)  User Status
# 19684        North Carolina  E-Cigarette Use (Youth)  User Status
# 19829  District of Columbia  E-Cigarette Use (Youth)  User Status
# 19911         Massachusetts  E-Cigarette Use (Youth)  User Status
# 20127              New York  E-Cigarette Use (Youth)  User Status
# 20163            New Mexico  E-Cigarette Use (Youth)  User Status
# 20191              Colorado  E-Cigarette Use (Youth)  User Status
# 20200              Illinois  E-Cigarette Use (Youth)  User Status
# 20226              Virginia  E-Cigarette Use (Youth)  User Status
# 20258         New Hampshire  E-Cigarette Use (Youth)  User Status
# 20339             Louisiana  E-Cigarette Use (Youth)  User Status
# 20441          Rhode Island  E-Cigarette Use (Youth)  User Status
#
#                       Frequency  % of Users Sample Size   Gender       Age  \
# 12806  Current E-Cigarette User        11.5        1804  Overall  All Ages
# 12812  Current E-Cigarette User         4.9        2428  Overall  All Ages
# 12883  Current E-Cigarette User        14.3        1385  Overall  All Ages
#
#                       State                 Use Type       Status  \
# 41                  Florida  E-Cigarette Use (Youth)  User Status
# 908                Delaware  E-Cigarette Use (Youth)  User Status
# 1271           South Dakota  E-Cigarette Use (Youth)  User Status
# 1406           Pennsylvania  E-Cigarette Use (Youth)  User Status
# 1838               Delaware  E-Cigarette Use (Youth)  User Status
# 1976                 Hawaii  E-Cigarette Use (Youth)  User Status
# 3107                Alabama  E-Cigarette Use (Youth)  User Status
# 3661               Missouri  E-Cigarette Use (Youth)  User Status
# 4445                Montana  E-Cigarette Use (Youth)  User Status
# 4955               Maryland  E-Cigarette Use (Youth)  User Status
# 5394                 Nevada  E-Cigarette Use (Youth)  User Status
# 5438           Rhode Island  E-Cigarette Use (Youth)  User Status
# 5742           Rhode Island  E-Cigarette Use (Youth)  User Status
# 5897             New Mexico  E-Cigarette Use (Youth)  User Status
# 6814                  Maine  E-Cigarette Use (Youth)  User Status
# 8221            Mississippi  E-Cigarette Use (Youth)  User Status
# 8225             New Mexico  E-Cigarette Use (Youth)  User Status
# 8782   District of Columbia  E-Cigarette Use (Youth)  User Status
# 8907          New Hampshire  E-Cigarette Use (Youth)  User Status
# 8986                 Hawaii  E-Cigarette Use (Youth)  User Status
# 9079                 Alaska  E-Cigarette Use (Youth)  User Status
# 10157         West Virginia  E-Cigarette Use (Youth)  User Status
# 10971  District of Columbia  E-Cigarette Use (Youth)  User Status
# 11022              Arkansas  E-Cigarette Use (Youth)  User Status
# 11647                 Idaho  E-Cigarette Use (Youth)  User Status
# 11899              Oklahoma  E-Cigarette Use (Youth)  User Status
# 12038          North Dakota  E-Cigarette Use (Youth)  User Status
# 12156              Maryland  E-Cigarette Use (Youth)  User Status
# 12224               Vermont  E-Cigarette Use (Youth)  User Status
# 12519             Tennessee  E-Cigarette Use (Youth)  User Status
# 15916            California  E-Cigarette Use (Youth)  User Status
# 16272              New York  E-Cigarette Use (Youth)  User Status
# 16500        South Carolina  E-Cigarette Use (Youth)  User Status
# 16523         Massachusetts  E-Cigarette Use (Youth)  User Status
# 18081              Virginia  E-Cigarette Use (Youth)  User Status
# 18720               Arizona  E-Cigarette Use (Youth)  User Status
# 18765              Michigan  E-Cigarette Use (Youth)  User Status
# 18818              Illinois  E-Cigarette Use (Youth)  User Status
# 18850              Kentucky  E-Cigarette Use (Youth)  User Status
# 19371              Kentucky  E-Cigarette Use (Youth)  User Status
# 21066         West Virginia  E-Cigarette Use (Youth)  User Status
# 21069               Indiana  E-Cigarette Use (Youth)  User Status
# 21136        North Carolina  E-Cigarette Use (Youth)  User Status
# 21217               Wyoming  E-Cigarette Use (Youth)  User Status
# 22227               Vermont  E-Cigarette Use (Youth)  User Status
# 22287              Virginia  E-Cigarette Use (Youth)  User Status
# 22494              Nebraska  E-Cigarette Use (Youth)  User Status
#
#                       Frequency  % of Users Sample Size   Gender       Age  \
# 41     Current E-Cigarette User         9.9        5752  Overall  All Ages
# 908    Current E-Cigarette User        23.5        2662  Overall  All Ages
# 1271   Current E-Cigarette User        17.3        1282  Overall  All Ages
# 1838   All Races     Current  Middle School  -75.577741  39.008831
# 1976   All Races     Current  Middle School -157.857749  21.304850
# 3107   All Races     Current    High School  -86.631861  32.840571
# 3661   All Races     Current    High School  -92.566300  38.635791
# 4445   All Races     Current    High School -109.424421  47.066529
# 4955   All Races     Current  Middle School  -76.609260  39.290581
# 5394   All Races     Current    High School -117.071841  39.493240
# 5438   All Races     Current  Middle School  -71.522470  41.708280
# 5742   All Races     Current    High School  -71.522470  41.708280
# 5897   All Races     Current    High School -106.240581  34.520881
# 6814   All Races     Current    High School  -68.985031  45.254229
# 8221   All Races     Current    High School  -89.538031  32.745510
# 8225   All Races     Current  Middle School -106.240581  34.520881
# 8782   All Races     Current  Middle School  -77.031961  38.890371
# 8907   All Races     Current    High School  -71.500361  43.655950
# 8986   All Races     Current    High School -157.857749  21.304850
# 9079   All Races     Current    High School -147.722059  64.845080
# 10157  All Races     Current    High School  -80.712640  38.665510
# 10971  All Races     Current    High School  -77.031961  38.890371
# 11022  All Races     Current    High School  -92.274491  34.748650
# 11647  All Races     Current    High School -114.363730  43.682630
# 11899  All Races     Current    High School  -97.521070  35.472031
# 12038  All Races     Current    High School -100.118421  47.475320
# 12156  All Races     Current    High School  -76.609260  39.290581
# 12224  All Races     Current  Middle School  -72.517641  43.625381
# 12519  All Races     Current    High School  -85.774491  35.680941
# 15916  All Races     Current    High School -121.000000  37.638640
# 16272  All Races     Current    High School  -75.543970  42.827001
# 16500  All Races     Current    High School  -81.045371  33.998821
# 16523  All Races     Current    High School  -72.082691  42.276870
# 18081  All Races     Current  Middle School  -78.457890  37.542681
# 18720  All Races     Current    High School -111.763811  34.865970
# 18765  All Races     Current    High School  -84.714390  44.661320
# 18818  All Races     Current    High School  -88.997710  40.485010
# 18850  All Races     Current  Middle School  -84.774971  37.645970
# 19371  All Races     Current    High School  -84.774971  37.645970
# 21066  All Races     Current  Middle School  -80.712640  38.665510
# 21069  All Races     Current    High School  -86.149960  39.766910
# 21136  All Races     Current    High School  -79.159250  35.466221
# 21217  All Races     Current    High School -108.109830  43.235541
# 22227  All Races     Current    High School  -72.517641  43.625381
# 22287  All Races     Current    High School  -78.457890  37.542681
# 22494  All Races     Current    High School  -99.365721  41.641041

# %%
# Store 'Lat' and 'Lng' into  locations 
locations2015 = ECig_2015[["Lat", "Lon"]].astype(float)

# Convert User Rate to float and store
Users2015 = ECig_2015["% of Users"].astype(float)

# %% [markdown]
# ### VISUAL 8: Heat Map of  E- Cigarette Users from 2015 USA

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations2015, weights=Users2015, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = 3

fig.add_layer(heat_layer)

fig
plt.savefig("VISUAL8.png")

plt.show()

# %%
# Store 'Lat' and 'Lng' into  locations 
locations2017 = ECig_2017[["Lat", "Lon"]].astype(float)

# Convert User Rate to float and store
Users2017 = ECig_2017["% of Users"].astype(float)

# %% [markdown]
# ### VISUAL 9: Heat Map of E-Cigerette Users from 2017 USA

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations2017, weights=Users2017, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = 3

fig.add_layer(heat_layer)

fig

plt.savefig("VISUAL9.png")

plt.show()

# %% [markdown]
# #### We Learned:  That heat maps can be tricky to display without API keys

# %% [markdown]
# ### VISUAL 10: Line Graph of Users Grouped by Usage Type

# %%
#drop ever and frequent users in "frequency" column
USA = USA[~USA['Frequency'].isin(['Ever Cigarette Smoker','Ever E-Cigarette User','Frequent Cigar Smoker','Frequent Cigarette Smoker','Frequent E-Cigarette User','Frequent Smokeless Tobacco User','Current Tobacco User'])]

# %%
# Line graph creation for all youth tobacco usage in the US by TYPE of use
USA[['% of Users']]=USA[['% of Users']].astype(float)
smoking_by_type = USA.groupby(['Year','Frequency']).mean()
fig, ax = plt.subplots(figsize=(8,8))
smoking_by_type.unstack().plot(ax=ax)
plt.title("Youth Tobacco Usage in U.S.", weight = "bold")
plt.xlabel("Years", weight = 'bold')
plt.ylabel("Percentage (%) of Users", weight = 'bold')
leg = ax.legend()

plt.savefig("VISUAL10.png")

plt.show()

# %%
# grouping by year, frequency and percentage of users from the USA dataframe. 
smoking_by_type = USA.groupby(['Year','Frequency']).mean()
smoking_by_type
# Out:
#                                      % of Users
# Year Frequency
# 1993 Current Cigarette Smoker         28.905208
# 1995 Current Cigarette Smoker         33.020370
#      Current Smokeless Tobacco User   11.957895
# 1997 Current Cigarette Smoker         34.436364
#      Current Smokeless Tobacco User    9.770833
# 1999 Current Cigar Smoker             16.243478
#      Current Cigarette Smoker         31.172358
#      Current Smokeless Tobacco User    8.832710
# 2001 Current Cigar Smoker             12.737500
#      Current Cigarette Smoker         22.510588
#      Current Smokeless Tobacco User    7.839610
# 2003 Current Cigar Smoker             12.339459
#      Current Cigarette Smoker         20.589423
#      Current Smokeless Tobacco User    7.218227
# 2005 Current Cigar Smoker             14.034197
#      Current Cigarette Smoker         19.631939
#      Current Smokeless Tobacco User    8.361304
# 2007 Current Cigar Smoker             12.197951
#      Current Cigarette Smoker         16.880503
#      Current Smokeless Tobacco User    7.940511
# 2009 Current Cigar Smoker             12.558305
#      Current Cigarette Smoker         15.806479
#      Current Smokeless Tobacco User    8.401471
# 2011 Current Cigar Smoker             11.311709
#      Current Cigarette Smoker         13.743583
#      Current Smokeless Tobacco User    7.717714
# 2013 Current Cigar Smoker             10.238122
#      Current Cigarette Smoker         10.667407
#      Current Smokeless Tobacco User    7.420681
# 2015 Current Cigar Smoker              9.096166
#      Current Cigarette Smoker          9.054875
#      Current E-Cigarette User         19.322189
#      Current Smokeless Tobacco User    7.066774
# 2017 Current Cigar Smoker              6.665854
#      Current Cigarette Smoker          6.881748
#      Current E-Cigarette User         12.726158
#      Current Smokeless Tobacco User    5.138710

# %% [markdown]
# ### VISUAL 11: Boxplot for Comparing Means for E-Cig All Usage by Gender in USA: ANOVA Test Performed

# %%
# Create a boxplot to compare means for E-Cig all Usage by Gender all over USA
USA_eCig.boxplot("% of Users", by="Gender", figsize=(20, 10))

plt.savefig("VISUAL11.png")

plt.show()

# %% [markdown]
# #### We Learned:  That the  inclusing of an overall category in the case of gender reduced the value of the testing we were performing

# %%
# Extract individual groups
group1 = USA_eCig[USA_eCig["Gender"] == "Female"]["% of Users"]
group2 = USA_eCig[USA_eCig["Gender"] == "Male"]["% of Users"]
group3 = USA_eCig[USA_eCig["Gender"] == "Overall"]["% of Users"]

# %%
# Perform the ANOVA
#A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis.
stats.f_oneway(group1, group2, group3)
# Out:
# F_onewayResult(statistic=2.3456118386558877, pvalue=0.09604548673887592)

# %%
# Create a boxplot to compare means for E-Cig Usage in 2015 & 2017 all over USA
USA_eCig_2015_17=USA_eCig.loc[(USA_eCig["Year"] =="2017")|(USA_eCig["Year"] =="2015")]

USA_eCig_2015_17.head()
# Out:
#     Location Code  Year           State                 Use Type       Status  \
# 41             NC  2015  North Carolina  E-Cigarette Use (Youth)  User Status
# 61             FL  2015         Florida  E-Cigarette Use (Youth)  User Status
# 89             NY  2015        New York  E-Cigarette Use (Youth)  User Status
# 107            VT  2015         Vermont  E-Cigarette Use (Youth)  User Status
# 133            VT  2015         Vermont  E-Cigarette Use (Youth)  User Status
#
#                      Frequency  % of Users Sample Size   Gender       Age  \
# 41       Ever E-Cigarette User        63.0         429  Overall  All Ages
# 61    Current E-Cigarette User         9.9        5752  Overall  All Ages
# 89   Frequent E-Cigarette User         4.8        2095  Overall  All Ages
# 107      Ever E-Cigarette User         7.4         362  Overall  All Ages
# 133  Frequent E-Cigarette User         0.8         365  Overall  All Ages
#
#                  Race User Status      Education  \
# 41      Multiple Race        Ever    High School
# 61          All Races     Current  Middle School
# 89              White    Frequent    High School
# 107  African American        Ever  Middle School
# 133  African American    Frequent  Middle School
#
#                                            geolocation
# 41   {'type': 'Point', 'coordinates': [-79.15925046...
# 61   {'type': 'Point', 'coordinates': [-81.92896053...
# 89   {'type': 'Point', 'coordinates': [-75.54397042...
# 107  {'type': 'Point', 'coordinates': [-72.51764079...
# 133  {'type': 'Point', 'coordinates': [-72.51764079...

# %% [markdown]
# ### VISUAL 12: Boxplot of Percentage of Users Grouped by Year: ANOVA Test Performed

# %%
# Extract individual groups
USA_eCig_2015_17.boxplot("% of Users", by="Year", figsize=(20, 10))

plt.savefig("VISUAL12.png")

plt.show()

# %%
# Extract individual groups
group1 = USA_eCig[USA_eCig["Year"] == "2015"]["% of Users"]
group2 = USA_eCig[USA_eCig["Year"] == "2017"]["% of Users"]

# %%
# Perform the ANOVA
#A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis.
stats.f_oneway(group1, group2)
# Out:
# F_onewayResult(statistic=19.592862428443475, pvalue=1.0085446000656468e-05)

# %% [markdown]
# ### VISUAL 13: Boxplot of Percentage of Users Grouped by Gender: ANOVA Test Performed
#                    #(removed All Gender category from earlier visual)

# %%
USA_eCig_MF=USA_eCig.loc[(USA_eCig["Gender"] =="Female")|(USA_eCig["Gender"] =="Male")]

USA_eCig_MF

plt.savefig("VISUAL13.png")

plt.show()

# %%
# Create a boxplot to compare means for E-Cig all Usage by Gender all over USA
USA_eCig_MF.boxplot("% of Users", by="Gender", figsize=(20, 10))

# %%
# Extract individual groups
group1 = USA_eCig[USA_eCig["Gender"] == "Female"]["% of Users"]
group2 = USA_eCig[USA_eCig["Gender"] == "Male"]["% of Users"]

# %%
# Perform the ANOVA
#A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis.
stats.f_oneway(group1, group2)
# Out:
# F_onewayResult(statistic=4.616410762730868, pvalue=0.032083628905618916)

# %% [markdown]
# ###  VISUAL 14: Boxplot of Percentage of E-Cig Users in 2015 - 2017: ANOVA Test Performed

# %%
http://localhost:8888/notebooks/Documents/GitHub/PROJECT1/FINAL%20PROJECT1.ipynb#VISUAL-14:-Boxplot-of-Percentage-of-E-Cig-Users-in-2015---2017:-ANOVA-Test-Performed# Create a boxplot to compare means for E-Cig Usage in 2015 & 2017 all over USA
USA_eCig_2015_17=USA_eCig.loc[(USA_eCig["Year"] =="2017")|(USA_eCig["Year"] =="2015")]

USA_eCig_2015_17.head()

plt.savefig("VISUAL14.png")

plt.show()
# Out:
#   File "<ipython-input-71-b645bc4b402a>", line 1
#     http://localhost:8888/notebooks/Documents/GitHub/PROJECT1/FINAL%20PROJECT1.ipynb#VISUAL-14:-Boxplot-of-Percentage-of-E-Cig-Users-in-2015---2017:-ANOVA-Test-Performed# Create a boxplot to compare means for E-Cig Usage in 2015 & 2017 all over USA
#           ^
# SyntaxError: invalid syntax

# %%
# Extract individual groups
USA_eCig_2015_17.boxplot("% of Users", by="Year", figsize=(20, 10))

# %%
# Extract individual groups
group1 = USA_eCig[USA_eCig["Year"] == "2015"]["% of Users"]
group2 = USA_eCig[USA_eCig["Year"] == "2017"]["% of Users"]

# %%
# Perform the ANOVA
#A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis.
stats.f_oneway(group1, group2)

# %% [markdown]
# ### VISUAL 15: Boxplot for Validating the Ethnicity Differences for 2015 - 2017

# %%
USA_eCig_Ethnicity_Minus_All_Races=USA_eCig.loc[USA_eCig["Race"] != "All Races"]
USA_eCig_Ethnicity_Minus_All_Races.head

# %%
# Extract individual groups
USA_eCig_Ethnicity_Minus_All_Races.boxplot("% of Users", by="Race", figsize=(20, 10))

plt.savefig("VISUAL15.png")

plt.show()

# %%
# Extract individual groups
group1 = USA_eCig_Ethnicity_Minus_All_Races[USA_eCig_Ethnicity_Minus_All_Races["Race"] == "African American"]["% of Users"]
group2 = USA_eCig_Ethnicity_Minus_All_Races[USA_eCig_Ethnicity_Minus_All_Races["Race"] == "American Indian/Alaska Native"]["% of Users"]
group3 = USA_eCig_Ethnicity_Minus_All_Races[USA_eCig_Ethnicity_Minus_All_Races["Race"] == "Asian"]["% of Users"]
group4 = USA_eCig_Ethnicity_Minus_All_Races[USA_eCig_Ethnicity_Minus_All_Races["Race"] == "Hispanic"]["% of Users"]
group5 = USA_eCig_Ethnicity_Minus_All_Races[USA_eCig_Ethnicity_Minus_All_Races["Race"] == "Multiple Race"]["% of Users"]
group6 = USA_eCig_Ethnicity_Minus_All_Races[USA_eCig_Ethnicity_Minus_All_Races["Race"] == "Pacific Islander"]["% of Users"]
group7 = USA_eCig_Ethnicity_Minus_All_Races[USA_eCig_Ethnicity_Minus_All_Races["Race"] == "White"]["% of Users"]

# %%
# Perform the ANOVA
#A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis.
stats.f_oneway(group1, group2,group3,group4,group5,group6,group7)

# %% [markdown]
# ## CONCLUSION:

# %% [markdown]
# ### Our conclusions for all measures and values demonstrated a clear downward trend line with a small increase in 2015, in which the tracking of e-cigarettes began for our data.  We could not find statistical proof of the 900% increase mentioned in the TED talk from our data.
#
# ### However, we do believe that if we repeated this study when the 2019 data is released for this survey, the conclusion would most likely change.
#
# ### It would also be of value, to pull other survey’s from the CDC as well as other health data sources, to compare all the values and track the impact of the introduction of e-cigarettes on the health of teens now as well as the impact of these same individuals as they age.   However, we needed to focus on the study of our one dataset for this project, so we could complete the work in time.
